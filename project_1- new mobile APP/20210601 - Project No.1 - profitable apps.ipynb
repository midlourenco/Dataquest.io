# %% [markdown]
# # What are the type of apps attract more users?
#
# ## 1. Introduction:
#
# This project aims to identify what are the more profitable app profiles for the App Store and Google Play markets.
#
# We are data analysts in a company which builds Android and iOS mobile app, and makes those apps available on Google Play and the App Store.
#
# Our developers only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means our revenue for any given app is mostly influenced by the number of users who use our app — the more users that see and engage with the ads, the better. Our goal for this project is to analyze data to help our developers understand what type of apps are likely to attract more users.
#
# To reach this objective we will need to collect and analyze data about mobile apps available on Google Play and App Store. We we will work with data of 2018 and a data sample reffers to more than 4 million apps (approximatelly 2 million regarding to iOS apps, and 2.1 million to Android apps).

# %% [markdown]
# ## 2. Exploring the dataset content:
# We will use existing data sets in order to save time and costs
# The data sets that we will use are:
# - Google Play: containing data about approximately 10,000 Android apps from Google Play; the data was collected in August 2018. We can download the data set directly from [this link](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv) .
# - App Store:containing data about approximately 7,000 iOS apps from the App Store; the data was collected in July 2017. You can download the data set directly from [this link](https://dq-content.s3.amazonaws.com/350/AppleStore.csv) .

# %% [markdown]
# First, we will open both files and transform them as a list.

# %%
from csv import reader

# open file referring to Android apps
openfile=open("/Users/midl/Documents/_Dataquest/mydatasets/project/googleplaystore.csv")
readfile=reader(openfile)
playstore_tt =list(readfile)
playstore_header=playstore_tt[0]
play_data=playstore_tt[1:]

#open file referring to iOS apps
openfile=open("/Users/midl/Documents/_Dataquest/mydatasets/project/AppleStore.csv")
readfile=reader(openfile)
istore_tt=list(readfile)
istore_header=istore_tt[0]
i_data=istore_tt[1:]

# %% [markdown]
# Now, we will start to explore data contents, using the following function:

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice=dataset[start:end]
    for row in dataset_slice:
        print(row)
        print('\n')
    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Numner of columnns', len(dataset[0]))

# %%
#checking first 4 rows of data of each dataset
print("\n" + "---Android apps: --- "+'\n')
explore_data(play_data,0, 4, True)
print("---iOS apps: --- "+'\n')
explore_data(i_data, 0, 4, True)
# Out:
# ---Android apps: ---
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# Number of rows: 10841
# Numner of columnns 13
# ---iOS apps: ---
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# Number of rows: 7197
# Numner of columnns 16

# %% [markdown]
# - **Checking this information, we can conclude that we have in total 10841 Andoid apps and 7197 iOS apps.**

# %%
#checking header of each dataset to identify the columns that could help us with our analysis.
print("Android columns names: ", "\n", playstore_header, "\n")

print("iOS columns names: ", "\n", istore_header, "\n")
# Out:
# Android columns names:
#  ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
# iOS columns names:
#  ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# - The column names of Android data are self-explanatory. However the column names of iOS data are not clear.
# - The explanation for the meaning of each column of iOS data is [in this link](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/home)
# - **Checking this information, we can conclude that the most interesting columns will be:**
#     - Android: "App", "Rating", "Installs", "Price", "Genres" and "Category".
#     - iOS: "track_name", "price", "rating_count_tot", "rating_count_ver", "user_rating", "prime_genre".

# %%
#checking price columns:
#android:
print(play_data[1][7])
#iOS:
print(i_data[1][4])
#checking langguage of app name is english:
#android:
print(play_data[1][0])
#iOS:
print(i_data[1][1])
# Out:
# 0
# 0.0
# Coloring book moana
# Instagram

# %% [markdown]
# ## 3. Data Cleaning
# Before start to analyse the datas, we need to check if there are some wrong information or mistakes in rows, to avoid wrong conclusions in our analyzes.
#
# Following we have some examples of tasks that we will need to check:
#  - remove inaccurate data / data with different numbers of column
#  - remove duplicate data
#  - remove non-English apps names
#  - remove the non-free apps:

# %% [markdown]
# ## 3.1. Remove the rows with different length
#
# **First Step:** The Google Play data set has a dedicated discussion section [here](https://www.kaggle.com/lava18/google-play-store-apps/discussion), and we can see that one of the discussions describes an error for a certain row. That row is the row number 10472.
# Let us check what is happening in that row:

# %%
print(playstore_header)
print(play_data[10472])
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %% [markdown]
# -> We know that Rating must be between 1 and 5. But when we saw this row number 10472, we can see something strange. The rating is 19.
# -> Let us check why is this happening?
# ->As mentioned in the discussions section (mention before), this problem is caused by a missing value in the 'Category' column. How can we inspect this? Bellow we are checking if it is missing one column information, and **we conclude that yes, it is missing information in one column.**
# -> This way **we will delete this row.**
# Note: After run this instruction to delete the wrong row, we wil comment the instruction, in order to prevent to run the instruction more than one time, and delete more than one row.

# %%
print(len(playstore_header))
print(len(play_data[10472]))
# Out:
# 13
# 12

# %%
#if we delete directly we will do:
#del play_data[10472]
#however, to be safe we will leave this instruction under comment, because we only can run it one time. It was already run. 
#as alternative we can do this inside the following for part of code

# %% [markdown]
# Now, let we check for both datasets, if we have more situation like the previous one. I mean with less or more columns than what we expect.

# %%
#inspect if we have more rows with different lenght than expected:
#android
i=[]
j=0
m=[]
for each in play_data:
    if len(each) != 13:#len information from result of explore_data()
        i.append(each)
        m.append(j)
    j+=1
    
print(i, m) # if i and m are empety lists, it means we don't have more any situation cause by this problem
print(len(play_data)) #this is just to double check that we will not delete more than one row. the initial number of rows were 10841


if len(m)==1:
    del play_data[m[0]]
print(len(play_data)) #this is just to double check that we will not delete more than one row. the initial number of rows were 10841

#iOS
i=[]
j=0
m=[]
for each in i_data:
    if len(each) != 16:#len information from result of explore_data()
        i.append(each)
        m.append(j)
    j+=1

print(i, m)# if i and m are empety lists, it means we don't have more any situation cause by this problem
print(len(i_data)) #this is just to double check that we will not delete more than one row. the initial number of rows were 7197
if len(m)==1:
    del play_data[m[0]]
print(len(play_data)) #this is just to double check that we will not delete more than one row. the initial number of rows were 10841
# Out:
# [['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']] [10472]
# 10841
# 10840
# [] []
# 7197
# 10840

# %%
#remove the non free apps?
play_nonfree=[]
j=0
for each in play_data:
    price=each[6]
    if price!="Free":
        play_nonfree.append(j)
    j+=1
print(len(play_nonfree)) #this is the total number of index which are not free
#print(play_nonfree) # these are the index that we will need to remove

i_nonfree=[]
j=0
for each in i_data:
    price=float(each[4])
    if price==0.0:
        i_nonfree.append(j)
    j+=1
print(len(i_nonfree)) #this is the total number of index which are not free
#print(i_nonfree) # these are the index that we will need to remove
# Out:
# 801
# 4056

# %% [markdown]
# ## 3.2. Remove the duplicate rows
# **Second step:** If you explore the Google Play data set long enough or look at the [discussions](https://www.kaggle.com/lava18/google-play-store-apps/discussion) section, we found that some apps have duplicate entries. For instance, Instagram has four entries.
#
# For each dataset, we need to identify how many rows we have in this situation and, then find the best way to remove the duplicate rows (we don't want to remove the rows randomly).
#
# Checking the example of Instagram, we can see that four entries have the same number of installers, but has different number of reviews. So, this allow us to understand that in this example,   the row with more reviews is the most recent one.
#
# So, at the end, we want to keep **the row with more reviews** and eliminate the others.
# To reach this goal we will do:
# - First goal - *identify dupplicates*: we construct a dictionary`play_name_freq` - for each app in the android dataset, we will register in this dictionationary its frequency (the number of times that it is in the data base). If one app has duplicated entries we saved its name in the list`duplicate_app` list.
# - Second goal - *identify the duplicated with more views*: for the apps which has duplicated entries, we construct another dictionary, the `reviews_max` with the app name and its maximum number of the reviews.
# - Third goal - *eliminate the duplicated rows with less reviews or same as the maximum reviews* - we will construct a lists `android_cleaned` with android data without dupplicate rows. However, we realize that only using the previous dictionary `reviews_max`, to insert condition reviews_max[name] == n_reviews, and then append those rows to our list, we will have more entries than lenght of previous dictionary. This means that we still will have some duplicated entries, which correspond to the entries of each app with same number of reviews (example: 'ZEDGE™ Ringtones & Wallpapers'). To avoid this situation, we create a second list `already_added` where we save the app name already in the data_cleaned and this way we make sure that we have only one entry per app.
#
#
# For iOS data, we stop on first dictionary, because we found each line as a different ID,so it means, there is not duplicate entry there.
#
#
# NOTES:
# Other criterias for "if we have more than one dupplicate app row with same number of reviews"
# 1. we tried to select one 2nd criteria: installers.
# We would select the one with more installers. However after some verifications, we understood that the installers are exact numbers of installation, but are only intervals of installation "5,000+" or "10,000+". This way, we think this is not relevant criteria in this analyze, so we will left this criteria behind. Anyway if we really want to use installers, we will need to remove "," and "+" and transform this in one int(), to can compare which number is bigger.
#
# 2. we also tried to check if we can use the last update as a solution for this situations.
# If we have same numbers of reviews, we are interested to select the most recent one.
# However after some inspections to the dataset we verified that we have lines complete the equals in the dataset (example: 'ZEDGE™ Ringtones & Wallpapers') -  this way for this situation we will need anyway to select one of them without any extra criteria.
#
# Let us move without any extra criteria.

# %% [markdown]
# --- EXAMPLE: Instagram ---

# %%
i=0
for each in play_data:
    name=each[0]
    review=int(each[3])
    if name== "Instagram":
        print(each)
        if review>i:
            i=review
max_rev_instagram=i
print("\n", "Max reviews for Instagram: ", max_rev_instagram)
# Out:
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577446', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66577313', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Instagram', 'SOCIAL', '4.5', '66509917', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Teen', 'Social', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#  Max reviews for Instagram:  66577446

# %% [markdown]
# --- EXAMPLE: ZEDGE™ Ringtones & Wallpapers ---

# %%
for each in play_data:
    name=each[0]
    review=int(each[3])
    if name== "ZEDGE™ Ringtones & Wallpapers":
        print(each)

print("\n", "We have 3 entries with max reviews of this app, and those entries are completely equals")
# Out:
# ['ZEDGE™ Ringtones & Wallpapers', 'PERSONALIZATION', '4.6', '6466641', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Personalization', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ['ZEDGE™ Ringtones & Wallpapers', 'PERSONALIZATION', '4.6', '6466641', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Personalization', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ['ZEDGE™ Ringtones & Wallpapers', 'PERSONALIZATION', '4.6', '6466641', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Personalization', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ['ZEDGE™ Ringtones & Wallpapers', 'PERSONALIZATION', '4.6', '6459626', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Personalization', 'July 19, 2018', 'Varies with device', 'Varies with device']
#
#  We have 3 entries with max reviews of this app, and those entries are completely equals

# %% [markdown]
# --- **Abstracting :** Checking duplicate rows ---

# %%
#Android
play_name_freq={}
duplicate_app=[]
reviews_max={}

for each in play_data:
    name=str(each[0])
    n_reviews=int(each[3])
    if name in play_name_freq:
        play_name_freq[name]+=1
        duplicate_app.append(name)
        if n_reviews>reviews_max[name]:
            reviews_max[name]=n_reviews
    else:
        play_name_freq[name]=1
        reviews_max[name]=n_reviews

        
print("\n", "ANDROID: ", "\n")

print("-> Examples of apps with dupplicate rows: ", duplicate_app[:5], "\n")

print("-> Total of duplicate apps' rows: ", len(duplicate_app), "\n")

print("Does it works for Instagram example?", max_rev_instagram==reviews_max["Instagram"], "\n")#checking if the dictionary gives the expected reviews number for Instgram attending what we saw before. If True, it means that we get same result as we expected

print("-> Expected total of apps without dupplicate rows: ", len(play_data)-len(duplicate_app))

print("-> Current total of apps without dupplicate rows: ", len(reviews_max), "\n")

print("Is the previsous expected number same as current number?", len(reviews_max)== len(play_data)-len(duplicate_app))

#print(play_name_freq)


#iOS

i_name_freq={}
duplicate_app=[]

for each in i_data:
    name=str(each[0])
    if name in i_name_freq:
        i_name_freq[name]+=1
        duplicate_app.append(name)
    else:
        i_name_freq[name]=1


print("\n", "iOS: ", "\n")

print("Examples of apps with dupplicate rows: ", duplicate_app[:5], "\n")

print("Total of duplicate apps' rows: ", len(duplicate_app), "\n")

#print(i_name_freq)
# Out:
#  ANDROID:
#
# -> Examples of apps with dupplicate rows:  ['Quick PDF Scanner + OCR FREE', 'Box', 'Google My Business', 'ZOOM Cloud Meetings', 'join.me - Simple Meetings']
#
# -> Total of duplicate apps' rows:  1181
#
# Does it works for Instagram example? True
#
# -> Expected total of apps without dupplicate rows:  9659
# -> Current total of apps without dupplicate rows:  9659
#
# Is the previsous expected number same as current number? True
#
#  iOS:
#
# Examples of apps with dupplicate rows:  []
#
# Total of duplicate apps' rows:  0

# %% [markdown]
# --- Deleting duplicates rows ---

# %%
android_cleaned=[]
already_added=[]

for each in play_data:
    name=str(each[0])
    n_reviews=int(each[3])
    if n_reviews== reviews_max[name] and name not in already_added:#we need to check why we have duplicate with same numbers of reviews and found another criteria
            android_cleaned.append(each)
            already_added.append(name)
# print(android_cleaned[:5])
print(len(android_cleaned))

#checking first 4 rows of data of each dataset
print("\n" + "---Android apps: --- "+'\n')
explore_data(android_cleaned,0, 4, True)
# Out:
# 9659
#
# ---Android apps: ---
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 9659
# Numner of columnns 13

# %% [markdown]
# ## 3.3. Remove non-English apps

# %% [markdown]
# We use English for the apps we develop at our company, and we'd like to analyze only the apps that are directed toward an English-speaking audience. However, if we explore the data long enough, we'll find that both data sets have apps with names that suggest they are not directed toward an English-speaking audience.
#
# In order to reach this objective, using the function `ord()` we will check the range number of each character in the App name. Knowing that the numbers corresponding to the characters we commonly use in an English text are all in the **range 0 to 127**, according to the ASCII (American Standard Code for Information Interchange) system, we can easily creat one function to check if APP name includes or not non-english characters.
#
# We create two version:
# - first version `english_v1`: we will exclude all apps which have at least 1 foreign character. We think this version is too stictly, and we will lose many workable entries, just because its name contains for example one emoji or trade mark symbol.
#
# - second version `english_v2`: we will exclude all apps which have 3 or more foreign characters.

# %%
from pprint import pprint

play_name_freq={}
duplicate_app=[]
list_dup_rev={}
reviews_max={}


#for each in play_data:
#    name=str(each[0])
#    n_reviews=int(each[3])
#    if n_reviews==reviews_max[name]:
#        list_dup_rev[name]= each
#print(len(list_dup_rev))
#pprint(reviews_max_dup)

#print(dup_rev)
for each in play_data:
    name=each[0]
    review=int(each[3])
    if name== "ZEDGE™ Ringtones & Wallpapers":
        print(each)
print(play_name_freq['ZEDGE™ Ringtones & Wallpapers'])
print(reviews_max['ZEDGE™ Ringtones & Wallpapers'])
print(list_dup_rev['ZEDGE™ Ringtones & Wallpapers'])
#print(reviews_max_dup['ZEDGE™ Ringtones & Wallpapers'])
# Out:
# ['ZEDGE™ Ringtones & Wallpapers', 'PERSONALIZATION', '4.6', '6466641', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Personalization', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ['ZEDGE™ Ringtones & Wallpapers', 'PERSONALIZATION', '4.6', '6466641', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Personalization', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ['ZEDGE™ Ringtones & Wallpapers', 'PERSONALIZATION', '4.6', '6466641', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Personalization', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ['ZEDGE™ Ringtones & Wallpapers', 'PERSONALIZATION', '4.6', '6459626', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Personalization', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-220-e2fb18ada875> in <module>
#      21     if name== "ZEDGE™ Ringtones & Wallpapers":
#      22         print(each)
# ---> 23 print(play_name_freq['ZEDGE™ Ringtones & Wallpapers'])
#      24 print(reviews_max['ZEDGE™ Ringtones & Wallpapers'])
#      25 print(list_dup_rev['ZEDGE™ Ringtones & Wallpapers'])
#
# KeyError: 'ZEDGE™ Ringtones & Wallpapers'

# %% [markdown]
# Examples of non-english entries in our data sets:

# %%
print("Android dataset")
print(android_cleaned[4412][0])
print(android_cleaned[7940][0], "\n")

print("iOS dataset")
print(i_data[813][1])
print(i_data[6731][1])
# Out:
# Android dataset
# 中国語 AQリスニング
# لعبة تقدر تربح DZ
#
# iOS dataset
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# 【脱出ゲーム】絶対に最後までプレイしないで 〜謎解き＆ブロックパズル〜

# %% [markdown]
# Checking if app name has non-English characteres:

# %%
print("---First vesion of function to check if we have an english name:---", "\n")
def english_v1(string):
    for each in string:
        if ord(each)>127:
            return False
    return True
print(english_v1("Instagram"), "-> This result is beacause all characters are english and range number is less than 127")
print(english_v1("爱奇艺PPS -《欢乐颂2》电视剧热播"), "-> This result is beacause name contains foreign characters")
print(english_v1("Docs To Go™ Free Office Suite"), "-> This result is beacause '™'', which has range number: ", ord("™"))
print(english_v1("Instachat 😜"), "-> This result is beacause emoji which has range number: ", ord("😜"),"\n")

print("---Second vesion of function to check if we have an english name:---", "\n")


def english_v2(string):
    tolerance=0
    for each in string:
        if ord(each)>127:
            tolerance+=1
            if tolerance>3:
                return False
    return True
print(english_v2("Instagram"), "-> This result is beacause all characters are english and range number is less than 127")
print(english_v2("爱奇艺PPS -《欢乐颂2》电视剧热播"), "-> This result is beacause name contains more than 3 foreign characters")
print(english_v2("Docs To Go™ Free Office Suite"), "-> This result is beacause we don't have more than 3 foreign characters")
print(english_v2("Instachat 😜"), "-> This result is beacause we don't have more than 3 foreign characters")


print("\n")
print("-> RESULTS: Android dataset")
play_en_cleaned=[]
play_nonenglish=[]

for each in android_cleaned:
    name=each[0]
    if english_v2(name):
        play_en_cleaned.append(each)
    else:
        play_nonenglish.append(each)

print ("Apps total with foreign name: ",len(play_nonenglish), "\n")
print ("Apps total removing the ones with foreign name: " , len(play_en_cleaned), "\n")


#checking results for android dataset:
for each in play_en_cleaned:
    name=each[0]
    #print (name)
for each in play_nonenglish:
    name=each[0]
    #print (name)
    
print("\n")
print("-> RESULTS: iOS dataset")
i_en_cleaned=[]
i_nonenglish=[]

for each in i_data:
    name=each[1]
    if english_v2(name):
        i_en_cleaned.append(each)
    else:
        i_nonenglish.append(each)

print ("Apps total with foreign name: ",len(i_nonenglish), "\n")
print ("Apps total removing the ones with foreign name: " , len(i_en_cleaned), "\n")

#checking results for ios dataset:
for each in i_en_cleaned:
    name=each[1]
    #print (name)
for each in i_nonenglish:
    name=each[1]
    #print (name)

print("-> EXPLORING DATASETS")
#checking first 4 rows of data of each dataset
print("\n" + "---Android apps: --- "+'\n')
explore_data(play_en_cleaned,0, 4, True)
print("---iOS apps: --- "+'\n')
explore_data(i_en_cleaned, 0, 4, True)
# Out:
# ---First vesion of function to check if we have an english name:---
#
# True -> This result is beacause all characters are english and range number is less than 127
# False -> This result is beacause name contains foreign characters
# False -> This result is beacause '™'', which has range number:  8482
# False -> This result is beacause emoji which has range number:  128540
#
# ---Second vesion of function to check if we have an english name:---
#
# True -> This result is beacause all characters are english and range number is less than 127
# False -> This result is beacause name contains more than 3 foreign characters
# True -> This result is beacause we don't have more than 3 foreign characters
# True -> This result is beacause we don't have more than 3 foreign characters
#
#
# -> RESULTS: Android dataset
# Apps total with foreign name:  45
#
# Apps total removing the ones with foreign name:  9614
#
#
#
# -> RESULTS: iOS dataset
# Apps total with foreign name:  1014
#
# Apps total removing the ones with foreign name:  6183
#
# -> EXPLORING DATASETS
#
# ---Android apps: ---
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 9614
# Numner of columnns 13
# ---iOS apps: ---
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# Number of rows: 6183
# Numner of columnns 16

# %% [markdown]
# ## 3.4. Remove non-free apps

# %% [markdown]
# In our company we only build free apps, so we want to remove from our datasets the non-free apps.

# %%
print("Android dataset")
play_en_free_cleaned=[]
play_en_nonfree_cleaned=[]
for each in play_en_cleaned:
    price=each[6]
    if price== "Free":
        play_en_free_cleaned.append(each)
    else:
        play_en_nonfree_cleaned.append(each)

print("\n")
print("\n")
print("iOS dataset")

i_en_free_cleaned=[]
i_en_nonfree_cleaned=[]
for each in i_en_cleaned:
    price=float(each[4])
    if price==0:
        i_en_free_cleaned.append(each)
    else:
        i_en_nonfree_cleaned.append(each)
        
print ("Free apps total in Android dataset: ",len(play_en_free_cleaned), "\n")
print ("Free apps total in iOS dataset: ", len(i_en_free_cleaned), "\n")

#checking results for android dataset:
for each in play_en_free_cleaned:
    price=each[6]
    #print (price)
for each in play_en_nonfree_cleaned:
    price=each[6]
    #print (price)
#checking results for android dataset:
for each in i_en_free_cleaned:
    price=each[4]
    #print (price)
for each in i_en_nonfree_cleaned:
    price=each[4]
    #print (price)

print("-> EXPLORING DATASETS")
#checking first 4 rows of data of each dataset
print("\n" + "---Android apps: --- "+'\n')
explore_data(play_en_free_cleaned,0, 4, True)
print("---iOS apps: --- "+'\n')
explore_data(i_en_free_cleaned, 0, 4, True)
# Out:
# Android dataset
#
#
#
#
# iOS dataset
# Free apps total in Android dataset:  8863
#
# Free apps total in iOS dataset:  3222
#
# -> EXPLORING DATASETS
#
# ---Android apps: ---
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Sketch - Draw & Paint', 'ART_AND_DESIGN', '4.5', '215644', '25M', '50,000,000+', 'Free', '0', 'Teen', 'Art & Design', 'June 8, 2018', 'Varies with device', '4.2 and up']
#
#
# ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', '4.3', '967', '2.8M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up']
#
#
# Number of rows: 8863
# Numner of columnns 13
# ---iOS apps: ---
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# ['420009108', 'Temple Run', '65921024', 'USD', '0.0', '1724546', '3842', '4.5', '4.0', '1.6.2', '9+', 'Games', '40', '5', '1', '1']
#
#
# Number of rows: 3222
# Numner of columnns 16

# %% [markdown]
# ## 4. Analyzing datasets

# %% [markdown]
# ## 4.1. Most common app by Genre
#
# *As we mentioned in the introduction, our aim is to determine the kinds of apps that are likely to attract more users because our revenue is highly influenced by the number of people using our apps.*
#
# *To minimize risks and overhead, our validation strategy for an app idea is comprised of three steps:*
#
#     Build a minimal Android version of the app, and add it to Google Play.
#     If the app has a good response from users, we develop it further.
#     If the app is profitable after six months, we build an iOS version of the app and add it to the App Store.
#
# *Because our end goal is to add the app on both Google Play and the App Store, we need to find app profiles that are successful on both markets. For instance, a profile that works well for both markets might be a productivity app that makes use of gamification.*
#
# *Let's begin the analysis by getting a sense of what are the most common genres for each market. For this, we'll need to build frequency tables for a few columns in our data sets.*

# %%
print("MOST COMMON GENRES for each dataset:")
#first we creat both frequency tables by hand
play_app_genre={}
for each in play_en_free_cleaned:
    genre=each[-4]
    if genre in play_app_genre:
        play_app_genre[genre]+=1
    else:
        play_app_genre[genre]=1
#print(play_app_genre)
#print("\n")
i_app_genre={}
for each in i_en_free_cleaned:
    genre=each[-5]
    if genre in i_app_genre:
        i_app_genre[genre]+=1
    else:
        i_app_genre[genre]=1
#print(i_app_genre)



print("-> Android dataset - most common genre")
freq_play=0
most_common=0
most_common_list=[]
for each in play_app_genre:
    if play_app_genre[each]>freq_play:
        freq_play=play_app_genre[each]
        most_common=each
    elif play_app_genre[each]==freq_play:
        most_common_list.append(each)
if len(most_common_list)==0:
        print("most common genre:", most_common," -> with frequence ", freq_play, " and percentage: ", (freq_play/len(play_en_free_cleaned)*100))   
else:
    print("check! we have 2 parameteres with exactly same percentage: ",most_common_list)       

print("\n")
print("-> iOS dataset - most common genre")
freq_i=0
most_common=0
most_common_list=[]
for each in i_app_genre:
    if i_app_genre[each]>freq_i:
        freq_i=i_app_genre[each]
        most_common=each
    elif i_app_genre[each]==freq_i:
        most_common_list.append(each)
if len(most_common_list)==0:
        print("most common genre:", most_common," -> with frequence: ", freq_i, "and percentage: ", (freq_i/len(i_en_free_cleaned)*100)) 
else:
    print("check! we have 2 parameteres with exactly same percentage: ",most_common_list)
# Out:
# MOST COMMON GENRES for each dataset:
# -> Android dataset - most common genre
# most common genre: Tools  -> with frequence  749  and percentage:  8.450863138892023
#
#
# -> iOS dataset - most common genre
# most common genre: Games  -> with frequence:  1874 and percentage:  58.16263190564867

# %%
print("CREATING FREQENCY TABLES FOR ANY COLUMN AND IN PERCENTAGES:")
#now we will create a function to avoid the previous "manual work"
def freq_table(dataset, index):
    app_parameter={}
    for each in dataset:
        parameter=each[index]
        if parameter in app_parameter:
            app_parameter[parameter]+=1
        else:
            app_parameter[parameter]=1
    app_parameter_percentage={}
    for each in app_parameter:
        app_parameter_percentage[each]=app_parameter[each]/len(dataset)*100
    return app_parameter_percentage

#following function will gave us most common parameter
def most_common(dataset, index):
    app_parameter_percentage=freq_table(dataset, index)
    freq=0
    most_common=0
    most_common_list=[]
    for each in app_parameter_percentage:
        if app_parameter_percentage[each]>freq:
            freq=app_parameter_percentage[each]
            most_common=each
        elif app_parameter_percentage[each]==freq:
            most_common_list.append(each)
    if len(most_common_list)==0:
        return print(most_common, freq)
    else:
        return print("check! we have 2 parameteres with exactly same percentage: ",most_common_list)

    
    
#freq_table(play_en_free_cleaned, -4)
#freq_table(i_en_free_cleaned, -5)
most_common(play_en_free_cleaned, -4)
most_common(i_en_free_cleaned, -5)
# Out:
# CREATING FREQENCY TABLES FOR ANY COLUMN AND IN PERCENTAGES:
# Tools 8.450863138892023
# Games 58.16263190564867

# %% [markdown]
# When we are analyzing the data, we may have interest to check all frequence table (instead we only check the most common item). However, the dictionary information are not following any sequence and so, it would be very hard checking results just printing the dictionary. This way, we need to see data ordenated by percentages. For that will use the following function to ordenate

# %%
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
print("**iOS data set: prime_genre**")
display_table(i_en_free_cleaned,-5)
# Out:
# **iOS data set: prime_genre**
# Games : 58.16263190564867
# Entertainment : 7.883302296710118
# Photo & Video : 4.9658597144630665
# Education : 3.662321539416512
# Social Networking : 3.2898820608317814
# Shopping : 2.60707635009311
# Utilities : 2.5139664804469275
# Sports : 2.1415270018621975
# Music : 2.0484171322160147
# Health & Fitness : 2.0173805090006205
# Productivity : 1.7380509000620732
# Lifestyle : 1.5828677839851024
# News : 1.3345747982619491
# Travel : 1.2414649286157666
# Finance : 1.1173184357541899
# Weather : 0.8690254500310366
# Food & Drink : 0.8069522036002483
# Reference : 0.5586592178770949
# Business : 0.5276225946617008
# Book : 0.4345127250155183
# Navigation : 0.186219739292365
# Medical : 0.186219739292365
# Catalogs : 0.12414649286157665

# %% [markdown]
# Let us start to analyze the frequency table you generated for the prime_genre column of the App Store data set. Checking this data, we can take the following conclusions:
#
# - The most common genre is **Games** with more than half entries in this dataset (58,16%)
# - The other patterns that we see are that after Games, the most common apps are Entertainment(7,88%),Photo & Video(4,96%), Education (3,66%) and than Social Networking (3.29%).
# - The general impression the is that the most of the apps are designed for entertainment (games, photo and video, social networking, sports, music) and not for practical purposes (education, shopping, utilities, productivity, lifestyle)
# - Based on this results we still cannot recommend an app profile for the App Store market, because even based on this frequency there's a large number of apps for **Games** we still didn't cehck if is this genre that have the largest number of users.

# %%
print("**1- Android data set: Genres**")
display_table(play_en_free_cleaned,-4)  
print("\n")
print("-----")
print("\n")
print("**2- Android data set: Category**")
display_table(play_en_free_cleaned,1)
# Out:
# **1- Android data set: Genres**
# Tools : 8.450863138892023
# Entertainment : 6.070179397495204
# Education : 5.348076272142616
# Business : 4.592124562789123
# Productivity : 3.8925871601038025
# Lifestyle : 3.8925871601038025
# Finance : 3.7007785174320205
# Medical : 3.5315355974275078
# Sports : 3.463838429425702
# Personalization : 3.317161232088458
# Communication : 3.2381812027530184
# Action : 3.102786866749408
# Health & Fitness : 3.0802211440821394
# Photography : 2.944826808078529
# News & Magazines : 2.798149610741284
# Social : 2.6627552747376737
# Travel & Local : 2.324269434728647
# Shopping : 2.245289405393208
# Books & Reference : 2.1437436533904997
# Simulation : 2.042197901387792
# Dating : 1.8616721200496444
# Arcade : 1.8503892587160102
# Video Players & Editors : 1.771409229380571
# Casual : 1.7601263680469368
# Maps & Navigation : 1.399074805370642
# Food & Drink : 1.241114746699763
# Puzzle : 1.128286133363421
# Racing : 0.9928917973598104
# Role Playing : 0.9364774906916393
# Libraries & Demo : 0.9364774906916393
# Auto & Vehicles : 0.9251946293580051
# Strategy : 0.9026289066907368
# House & Home : 0.8236488773552973
# Weather : 0.8010831546880289
# Events : 0.7108202640189552
# Adventure : 0.6769716800180525
# Comics : 0.6092745120162473
# Beauty : 0.5979916506826132
# Art & Design : 0.5979916506826132
# Parenting : 0.4964458986799052
# Card : 0.4513144533453684
# Casino : 0.42874873067809993
# Trivia : 0.4174658693444658
# Educational;Education : 0.3949001466771973
# Board : 0.38361728534356315
# Educational : 0.37233442400992894
# Education;Education : 0.33848584000902626
# Word : 0.25950581067358686
# Casual;Pretend Play : 0.2369400880063184
# Music : 0.20309150400541578
# Racing;Action & Adventure : 0.16924292000451313
# Puzzle;Brain Games : 0.16924292000451313
# Entertainment;Music & Video : 0.16924292000451313
# Casual;Brain Games : 0.1353943360036105
# Casual;Action & Adventure : 0.1353943360036105
# Arcade;Action & Adventure : 0.1241114746699763
# Action;Action & Adventure : 0.10154575200270789
# Educational;Pretend Play : 0.09026289066907367
# Simulation;Action & Adventure : 0.07898002933543948
# Parenting;Education : 0.07898002933543948
# Entertainment;Brain Games : 0.07898002933543948
# Board;Brain Games : 0.07898002933543948
# Parenting;Music & Video : 0.06769716800180525
# Educational;Brain Games : 0.06769716800180525
# Casual;Creativity : 0.06769716800180525
# Art & Design;Creativity : 0.06769716800180525
# Education;Pretend Play : 0.05641430666817105
# Role Playing;Pretend Play : 0.045131445334536835
# Education;Creativity : 0.045131445334536835
# Role Playing;Action & Adventure : 0.033848584000902626
# Puzzle;Action & Adventure : 0.033848584000902626
# Entertainment;Creativity : 0.033848584000902626
# Entertainment;Action & Adventure : 0.033848584000902626
# Educational;Creativity : 0.033848584000902626
# Educational;Action & Adventure : 0.033848584000902626
# Education;Music & Video : 0.033848584000902626
# Education;Brain Games : 0.033848584000902626
# Education;Action & Adventure : 0.033848584000902626
# Adventure;Action & Adventure : 0.033848584000902626
# Video Players & Editors;Music & Video : 0.022565722667268417
# Sports;Action & Adventure : 0.022565722667268417
# Simulation;Pretend Play : 0.022565722667268417
# Puzzle;Creativity : 0.022565722667268417
# Music;Music & Video : 0.022565722667268417
# Entertainment;Pretend Play : 0.022565722667268417
# Casual;Education : 0.022565722667268417
# Board;Action & Adventure : 0.022565722667268417
# Video Players & Editors;Creativity : 0.011282861333634209
# Trivia;Education : 0.011282861333634209
# Travel & Local;Action & Adventure : 0.011282861333634209
# Tools;Education : 0.011282861333634209
# Strategy;Education : 0.011282861333634209
# Strategy;Creativity : 0.011282861333634209
# Strategy;Action & Adventure : 0.011282861333634209
# Simulation;Education : 0.011282861333634209
# Role Playing;Brain Games : 0.011282861333634209
# Racing;Pretend Play : 0.011282861333634209
# Puzzle;Education : 0.011282861333634209
# Parenting;Brain Games : 0.011282861333634209
# Music & Audio;Music & Video : 0.011282861333634209
# Lifestyle;Pretend Play : 0.011282861333634209
# Lifestyle;Education : 0.011282861333634209
# Health & Fitness;Education : 0.011282861333634209
# Health & Fitness;Action & Adventure : 0.011282861333634209
# Entertainment;Education : 0.011282861333634209
# Communication;Creativity : 0.011282861333634209
# Comics;Creativity : 0.011282861333634209
# Casual;Music & Video : 0.011282861333634209
# Card;Action & Adventure : 0.011282861333634209
# Books & Reference;Education : 0.011282861333634209
# Art & Design;Pretend Play : 0.011282861333634209
# Art & Design;Action & Adventure : 0.011282861333634209
# Arcade;Pretend Play : 0.011282861333634209
# Adventure;Education : 0.011282861333634209
#
#
# -----
#
#
# **2- Android data set: Category**
# FAMILY : 18.898792733837304
# GAME : 9.725826469592688
# TOOLS : 8.462146000225657
# BUSINESS : 4.592124562789123
# LIFESTYLE : 3.9038700214374367
# PRODUCTIVITY : 3.8925871601038025
# FINANCE : 3.7007785174320205
# MEDICAL : 3.5315355974275078
# SPORTS : 3.396141261423897
# PERSONALIZATION : 3.317161232088458
# COMMUNICATION : 3.2381812027530184
# HEALTH_AND_FITNESS : 3.0802211440821394
# PHOTOGRAPHY : 2.944826808078529
# NEWS_AND_MAGAZINES : 2.798149610741284
# SOCIAL : 2.6627552747376737
# TRAVEL_AND_LOCAL : 2.335552296062281
# SHOPPING : 2.245289405393208
# BOOKS_AND_REFERENCE : 2.1437436533904997
# DATING : 1.8616721200496444
# VIDEO_PLAYERS : 1.7939749520478394
# MAPS_AND_NAVIGATION : 1.399074805370642
# FOOD_AND_DRINK : 1.241114746699763
# EDUCATION : 1.1621347173643235
# ENTERTAINMENT : 0.9590432133589079
# LIBRARIES_AND_DEMO : 0.9364774906916393
# AUTO_AND_VEHICLES : 0.9251946293580051
# HOUSE_AND_HOME : 0.8236488773552973
# WEATHER : 0.8010831546880289
# EVENTS : 0.7108202640189552
# PARENTING : 0.6544059573507841
# ART_AND_DESIGN : 0.6431230960171499
# COMICS : 0.6205573733498815
# BEAUTY : 0.5979916506826132

# %% [markdown]
# Now looking for the other frequency tables generated for the Category and Genres column of the Google Play data set, we can take the following conclusions:
#
# - The most common genres are **Tools** (8,45%), **Entertainment**(6,07%)and **Education**(5,35%) and the most common Categories are **FAMILY** (18,90%) , **GAME** (9.72%) and **TOOLS** (8.46%)
# - The other patterns that we can see is that beside top 3, the other categories and genres on top of table are more regarding pratical purpose than entertainment.
# - Comparing the patterns for the Google Play market with what we saw for the App Store market, we can see the opposite trend. For Google Play, the general impression the is that the most of the apps are designed for practical purposes (education, shopping, utilities, productivity, lifestyle)than for entertainment (games, photo and video, social networking, sports, music)
# - We cannot recommend an app profile based on what we found until now. We need to compare this numbers with numbers of installers/reviews, in order to understand which apps has more users.

# %% [markdown]
# ## 4.2. Most common app by Genre attending user number

# %% [markdown]
# ### 4.2.1. Most common app by Genre attending user number - iOS dataset

# %% [markdown]
# *Now, we'd like to get an idea about the kind of apps with the most users.*
#
# *One way to find out what genres are the most popular (have the most users) is to calculate the average number of installs for each app genre. *
# For the Google Play data set, we can find this information in the `Installs` column.
# For the App Store data set, we'll take the total number of user ratings as a proxy, which we can find in the `rating_count_tot app`.

# %%
print("iOS data set: prime_genre", "\n")

i_genre_dic= freq_table(i_en_free_cleaned,-5)

table_display=[]
for genre in i_genre_dic:
    total=0
    len_genre=0
    for each in i_en_free_cleaned:
        installers= float(each[5])
        genre_app=each[-5]
        if genre_app==genre:
            total +=installers
            len_genre+=1
    average=total/len_genre
    genre_tupples=(average, genre)
    table_display.append(genre_tupples)
    #print(genre, ": ", average)
    #print(genre_tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0])
# Out:
# iOS data set: prime_genre
#
# Navigation : 86090.33333333333
# Reference : 74942.11111111111
# Social Networking : 71548.34905660378
# Music : 57326.530303030304
# Weather : 52279.892857142855
# Book : 39758.5
# Food & Drink : 33333.92307692308
# Finance : 31467.944444444445
# Photo & Video : 28441.54375
# Travel : 28243.8
# Shopping : 26919.690476190477
# Health & Fitness : 23298.015384615384
# Sports : 23008.898550724636
# Games : 22788.6696905016
# News : 21248.023255813954
# Productivity : 21028.410714285714
# Utilities : 18684.456790123455
# Lifestyle : 16485.764705882353
# Entertainment : 14029.830708661417
# Business : 7491.117647058823
# Education : 7003.983050847458
# Catalogs : 4004.0
# Medical : 612.0

# %% [markdown]
# --> On average, navigation apps have the highest number of user reviews
# Let us jump deep inside navigation data information and saw what are the apps inside this genre versus the numbers of users:

# %%
table_display=[]
for each in i_en_free_cleaned:
    if each[-5] == 'Navigation':
        tupples=(int(each[5]), each[1])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Google Maps - Navigation & Transit : 154911
# Geocaching® : 12811
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5

# %% [markdown]
# --> We can see that inside Naviagtion, we have 2 apps with the biggest part of the users:  Waze and Google Maps. - These market is dominated by this gigants so should not be what we are looking for.

# %% [markdown]
# Let us check what happened inside each other genre:

# %%
table_display=[]
for each in i_en_free_cleaned:
    if each[-5] == 'Reference':
        tupples=(int(each[5]), each[1])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Google Translate : 26786
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# Merriam-Webster Dictionary : 16849
# Night Sky : 12122
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# WWDC : 762
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# VPN Express : 14
# Real Bike Traffic Rider Virtual Reality Glasses : 8
# 教えて!goo : 0
# Jishokun-Japanese English Dictionary & Translator : 0

# %% [markdown]
# --> Inside references we have also 2 apps with the biggest part of the users: Bible and Dictionary.com, where Bible is much more users. This looks insteresting.

# %%
table_display=[]
for each in i_en_free_cleaned:
    if each[-5] == 'Social Networking':
        tupples=(int(each[5]), each[1])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Facebook : 2974676
# Pinterest : 1061624
# Skype for iPhone : 373519
# Messenger : 351466
# Tumblr : 334293
# WhatsApp Messenger : 287589
# Kik : 260965
# ooVoo – Free Video Call, Text and Voice : 177501
# TextNow - Unlimited Text + Calls : 164963
# Viber Messenger – Text & Call : 164249
# Followers - Social Analytics For Instagram : 112778
# MeetMe - Chat and Meet New People : 97072
# We Heart It - Fashion, wallpapers, quotes, tattoos : 90414
# InsTrack for Instagram - Analytics Plus More : 85535
# Tango - Free Video Call, Voice and Chat : 75412
# LinkedIn : 71856
# Match™ - #1 Dating App. : 60659
# Skype for iPad : 60163
# POF - Best Dating App for Conversations : 52642
# Timehop : 49510
# Find My Family, Friends & iPhone - Life360 Locator : 43877
# Whisper - Share, Express, Meet : 39819
# Hangouts : 36404
# LINE PLAY - Your Avatar World : 34677
# WeChat : 34584
# Badoo - Meet New People, Chat, Socialize. : 34428
# Followers + for Instagram - Follower Analytics : 28633
# GroupMe : 28260
# Marco Polo Video Walkie Talkie : 27662
# Miitomo : 23965
# SimSimi : 23530
# Grindr - Gay and same sex guys chat, meet and date : 23201
# Wishbone - Compare Anything : 20649
# imo video calls and chat : 18841
# After School - Funny Anonymous School News : 18482
# Quick Reposter - Repost, Regram and Reshare Photos : 17694
# Weibo HD : 16772
# Repost for Instagram : 15185
# Live.me – Live Video Chat & Make Friends Nearby : 14724
# Nextdoor : 14402
# Followers Analytics for Instagram - InstaReport : 13914
# YouNow: Live Stream Video Chat : 12079
# FollowMeter for Instagram - Followers Tracking : 11976
# LINE : 11437
# eHarmony™ Dating App - Meet Singles : 11124
# Discord - Chat for Gamers : 9152
# QQ : 9109
# Telegram Messenger : 7573
# Weibo : 7265
# Periscope - Live Video Streaming Around the World : 6062
# Chat for Whatsapp - iPad Version : 5060
# QQ HD : 5058
# Followers Analysis Tool For Instagram App Free : 4253
# live.ly - live video streaming : 4145
# Houseparty - Group Video Chat : 3991
# SOMA Messenger : 3232
# Monkey : 3060
# Down To Lunch : 2535
# Flinch - Video Chat Staring Contest : 2134
# Highrise - Your Avatar Community : 2011
# LOVOO - Dating Chat : 1985
# PlayStation®Messages : 1918
# BOO! - Video chat camera with filters & stickers : 1805
# Qzone : 1649
# Chatous - Chat with new people : 1609
# Kiwi - Q&A : 1538
# GhostCodes - a discovery app for Snapchat : 1313
# Jodel : 1193
# FireChat : 1037
# Google Duo - simple video calling : 1033
# Fiesta by Tango - Chat & Meet New People : 885
# Google Allo — smart messaging : 862
# Peach — share vividly : 727
# Hey! VINA - Where Women Meet New Friends : 719
# Battlefield™ Companion : 689
# All Devices for WhatsApp - Messenger for iPad : 682
# Chat for Pokemon Go - GoChat : 500
# IAmNaughty – Dating App to Meet New People Online : 463
# Qzone HD : 458
# Zenly - Locate your friends in realtime : 427
# League of Legends Friends : 420
# 豆瓣 : 407
# Candid - Speak Your Mind Freely : 398
# 知乎 : 397
# Selfeo : 366
# Fake-A-Location Free ™ : 354
# Popcorn Buzz - Free Group Calls : 281
# Fam — Group video calling for iMessage : 279
# QQ International : 274
# Ameba : 269
# SoundCloud Pulse: for creators : 240
# Tantan : 235
# Cougar Dating & Life Style App for Mature Women : 213
# Rawr Messenger - Dab your chat : 180
# WhenToPost: Best Time to Post Photos for Instagram : 158
# Inke—Broadcast an amazing life : 147
# Mustknow - anonymous video Q&A : 53
# CTFxCmoji : 39
# Lobi : 36
# Chain: Collaborate On MyVideo Story/Group Video : 35
# botman - Real time video chat : 7
# niconico ch : 0
# bit-tube - Live Stream Video Chat : 0
# MATCH ON LINE chat : 0
# LINE BLOG : 0
# BestieBox : 0

# %% [markdown]
# --> Inside references we have also some apps with the biggest part of the users: Facebook
# , Pinterest and Skype. This market looks to also be dominated by these gigants so should not be what we are looking for.

# %%
table_display=[]
for each in i_en_free_cleaned:
    if each[-5] == 'Music':
        tupples=(int(each[5]), each[1])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Pandora - Music & Radio : 1126879
# Spotify Music : 878563
# Shazam - Discover music, artists, videos & lyrics : 402925
# iHeartRadio – Free Music & Radio Stations : 293228
# SoundCloud - Music & Audio : 135744
# Magic Piano by Smule : 131695
# Smule Sing! : 119316
# TuneIn Radio - MLB NBA Audiobooks Podcasts Music : 110420
# Amazon Music : 106235
# SoundHound Song Search & Music Player : 82602
# Sonos Controller : 48905
# Bandsintown Concerts : 30845
# Karaoke - Sing Karaoke, Unlimited Songs! : 28606
# My Mixtapez Music : 26286
# Sing Karaoke Songs Unlimited with StarMaker : 26227
# Ringtones for iPhone & Ringtone Maker : 25403
# Musi - Unlimited Music For YouTube : 25193
# AutoRap by Smule : 18202
# Spinrilla - Mixtapes For Free : 15053
# Napster - Top Music & Radio : 14268
# edjing Mix:DJ turntable to remix and scratch music : 13580
# Free Music - MP3 Streamer & Playlist Manager Pro : 13443
# Free Piano app by Yokee : 13016
# Google Play Music : 10118
# Certified Mixtapes - Hip Hop Albums & Mixtapes : 9975
# TIDAL : 7398
# YouTube Music : 7109
# Nicki Minaj: The Empire : 5196
# Sounds app - Music And Friends : 5126
# SongFlip - Free Music Streamer : 5004
# Simple Radio - Live AM & FM Radio Stations : 4787
# Deezer - Listen to your Favorite Music & Playlists : 4677
# Ringtones for iPhone with Ringtone Maker : 4013
# Bose SoundTouch : 3687
# Amazon Alexa : 3018
# DatPiff : 2815
# Trebel Music - Unlimited Music Downloader : 2570
# Free Music Play - Mp3 Streamer & Player : 2496
# Acapella from PicPlayPost : 2487
# Coach Guitar - Lessons & Easy Tabs For Beginners : 2416
# Musicloud - MP3 and FLAC Music Player for Cloud Platforms. : 2211
# Piano - Play Keyboard Music Games with Magic Tiles : 1636
# Boom: Best Equalizer & Magical Surround Sound : 1375
# Music Freedom - Unlimited Free MP3 Music Streaming : 1246
# AmpMe - A Portable Social Party Music Speaker : 1047
# Medly - Music Maker : 933
# Bose Connect : 915
# Music Memos : 909
# UE BOOM : 612
# LiveMixtapes : 555
# NOISE : 355
# MP3 Music Player & Streamer for Clouds : 329
# Musical Video Maker - Create Music clips lip sync : 320
# Cloud Music Player - Downloader & Playlist Manager : 319
# Remixlive - Remix loops with pads : 288
# QQ音乐HD : 224
# Blocs Wave - Make & Record Music : 158
# PlayGround • Music At Your Fingertips : 150
# Music and Chill : 135
# The Singing Machine Mobile Karaoke App : 130
# radio.de - Der Radioplayer : 64
# Free Music -  Player & Streamer  for Dropbox, OneDrive & Google Drive : 46
# NRJ Radio : 38
# Smart Music: Streaming Videos and Radio : 17
# BOSS Tuner : 13
# PetitLyrics : 0

# %% [markdown]
# --> Inside references we have also some apps with the biggest part of the users: Pandora , Spotify and Shazam.  This market looks to also be dominated by these gigants so should not be what we are looking for.

# %%
table_display=[]
for each in i_en_free_cleaned:
    if each[-5] == 'Weather':
        tupples=(int(each[5]), each[1])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# The Weather Channel: Forecast, Radar & Alerts : 495626
# The Weather Channel App for iPad – best local forecast, radar map, and storm tracking : 208648
# WeatherBug - Local Weather, Radar, Maps, Alerts : 188583
# MyRadar NOAA Weather Radar Forecast : 150158
# AccuWeather - Weather for Life : 144214
# Yahoo Weather : 112603
# Weather Underground: Custom Forecast & Local Radar : 49192
# NOAA Weather Radar - Weather Forecast & HD Radar : 45696
# Weather Live Free - Weather Forecast & Alerts : 35702
# Storm Radar : 22792
# QuakeFeed Earthquake Map, Alerts, and News : 6081
# Moji Weather - Free Weather Forecast : 2333
# Hurricane by American Red Cross : 1158
# Forecast Bar : 375
# Hurricane Tracker WESH 2 Orlando, Central Florida : 203
# FEMA : 128
# iWeather - World weather forecast : 80
# Weather - Radar - Storm with Morecast App : 78
# Yurekuru Call : 53
# Weather & Radar : 37
# WRAL Weather Alert : 25
# Météo-France : 24
# JaxReady : 22
# Freddy the Frogcaster's Weather Station : 14
# Almanac Long-Range Weather Forecast : 12
# wetter.com : 0
# WarnWetter : 0
# TodayAir : 0

# %% [markdown]
# --> For weather, we gave some gigants and we may take in attention that we cannot create much more, and this kind of apps are usually for quick use

# %%
table_display=[]
for each in i_en_free_cleaned:
    if each[-5] == 'Book':
        tupples=(int(each[5]), each[1])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Kindle – Read eBooks, Magazines & Textbooks : 252076
# Audible – audio books, original series & podcasts : 105274
# Color Therapy Adult Coloring Book for Adults : 84062
# OverDrive – Library eBooks and Audiobooks : 65450
# HOOKED - Chat Stories : 47829
# BookShout: Read eBooks & Track Your Reading Goals : 879
# Dr. Seuss Treasury — 50 best kids books : 451
# Green Riding Hood : 392
# Weirdwood Manor : 197
# MangaZERO - comic reader : 9
# 謎解き2016 : 0
# 謎解き : 0
# ikouhoushi : 0
# MangaTiara - love comic reader : 0

# %% [markdown]
# --> For Book it looks interesting. There are not many apps. We may have space to entry.

# %%
table_display=[]
for each in i_en_free_cleaned:
    if each[-5] == 'Food & Drink':
        tupples=(int(each[5]), each[1])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Starbucks : 303856
# Domino's Pizza USA : 258624
# OpenTable - Restaurant Reservations : 113936
# Allrecipes Dinner Spinner : 109349
# DoorDash - Food Delivery : 25947
# UberEATS: Uber for Food Delivery : 17865
# Postmates - Food Delivery, Faster : 9519
# Dunkin' Donuts - Get Offers, Coupons & Rewards : 9068
# Chick-fil-A : 5665
# McDonald's : 4050
# Deliveroo: Restaurant Delivery - Order Food Nearby : 1702
# SONIC Drive-In : 1645
# Nowait Guest : 1625
# 7-Eleven, Inc. : 1356
# Outback : 805
# Bon Appetit : 750
# Starbucks Keyboard : 457
# Whataburger : 197
# Delish Eatmoji Keyboard : 154
# Lieferheld - Delicious food delivery service : 29
# Lieferando.de : 29
# McDo France : 22
# Chefkoch - Rezepte, Kochen, Backen & Kochbuch : 20
# Youmiam : 9
# Marmiton Twist : 2
# Open Food Facts : 1

# %% [markdown]
# --> For Food and Drink, if we excludes the 2 first apps, because are from specific restaurantes, we will found apps for restaurant reservations, apps for deliveries and apps for receipts. This is interesting and we should have space to entry.

# %% [markdown]
# Looking for these genres and conclusions we took for each one, the profile APPs that we suggest for iOS market is:
# - Reference: edit one known book
# - Book: think about a new reader
# - Food and drink: there is different ways to go

# %% [markdown]
# ### 4.2.2. Most common app by Genre attending user number - Android dataset

# %% [markdown]
# As we had already verified the installers numbers on Android dataset are not precise numbers. Even so they are strings because have "," and "+". Knowing about the method `str.replace()`we can now easily transform installers in integer.

# %%
#play_genre_dic= freq_table(play_en_free_cleaned,-4)
play_categ_dic= freq_table(play_en_free_cleaned,1)

table_display=[]
#for genre in play_genre_dic:
for categ in play_categ_dic:
    total=0
    #len_genre=0
    len_categ=0
    for each in play_en_free_cleaned:
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        #genre_app=each[-4]
        categ_app=each[1]
        #if genre_app==genre:
        if categ_app==categ:
            total +=installers
            len_categ+=1
            #len_genre+=1
    average=total/len_categ
    #average=total/len_genre
    tupples=(average, categ)
    table_display.append(tupples)
    #print(categ, ": ", average)
    #print(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0])
# Out:
# COMMUNICATION : 38456119.167247385
# VIDEO_PLAYERS : 24727872.452830188
# SOCIAL : 23253652.127118643
# PHOTOGRAPHY : 17840110.40229885
# PRODUCTIVITY : 16787331.344927534
# GAME : 15588015.603248259
# TRAVEL_AND_LOCAL : 13984077.710144928
# ENTERTAINMENT : 11640705.88235294
# TOOLS : 10801391.298666667
# NEWS_AND_MAGAZINES : 9549178.467741935
# BOOKS_AND_REFERENCE : 8767811.894736841
# SHOPPING : 7036877.311557789
# PERSONALIZATION : 5201482.6122448975
# WEATHER : 5074486.197183099
# HEALTH_AND_FITNESS : 4188821.9853479853
# MAPS_AND_NAVIGATION : 4056941.7741935486
# FAMILY : 3697848.1731343283
# SPORTS : 3638640.1428571427
# ART_AND_DESIGN : 1986335.0877192982
# FOOD_AND_DRINK : 1924897.7363636363
# EDUCATION : 1833495.145631068
# BUSINESS : 1712290.1474201474
# LIFESTYLE : 1437816.2687861272
# FINANCE : 1387692.475609756
# HOUSE_AND_HOME : 1331540.5616438356
# DATING : 854028.8303030303
# COMICS : 817657.2727272727
# AUTO_AND_VEHICLES : 647317.8170731707
# LIBRARIES_AND_DEMO : 638503.734939759
# PARENTING : 542603.6206896552
# BEAUTY : 513151.88679245283
# EVENTS : 253542.22222222222
# MEDICAL : 120550.61980830671

# %% [markdown]
# --> On average, communication apps have the highest number of user reviews Let us jump deep inside communication data information and saw what are the apps inside this genre versus the numbers of users:

# %%
table_display=[]
for each in play_en_free_cleaned:
    if each[1] == 'COMMUNICATION':
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        tupples=(installers, each[0])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# WhatsApp Messenger : 1000000000
# Skype - free IM & video calls : 1000000000
# Messenger – Text and Video Chat for Free : 1000000000
# Hangouts : 1000000000
# Google Chrome: Fast & Secure : 1000000000
# Gmail : 1000000000
# imo free video calls and chat : 500000000
# Viber Messenger : 500000000
# UC Browser - Fast Download Private & Secure : 500000000
# LINE: Free Calls & Messages : 500000000
# Google Duo - High Quality Video Calls : 500000000
# imo beta free calls and text : 100000000
# Yahoo Mail – Stay Organized : 100000000
# Who : 100000000
# WeChat : 100000000
# UC Browser Mini -Tiny Fast Private & Secure : 100000000
# Truecaller: Caller ID, SMS spam blocking & Dialer : 100000000
# Telegram : 100000000
# Opera Mini - fast web browser : 100000000
# Opera Browser: Fast and Secure : 100000000
# Messenger Lite: Free Calls & Messages : 100000000
# Kik : 100000000
# KakaoTalk: Free Calls & Text : 100000000
# GO SMS Pro - Messenger, Free Themes, Emoji : 100000000
# Firefox Browser fast & private : 100000000
# BBM - Free Calls & Messages : 100000000
# Android Messages : 100000000
# free video calls and chat : 50000000
# Zalo – Video Call : 50000000
# Mail.Ru - Email App : 50000000
# Dolphin Browser - Fast, Private & Adblock🐬 : 50000000
# Contacts : 50000000
# CM Browser - Ad Blocker , Fast Download , Privacy : 50000000
# Azar : 50000000
# myMail – Email for Hotmail, Gmail and Outlook Mail : 10000000
# chomp SMS : 10000000
# ZenUI Dialer & Contacts : 10000000
# Xperia Link™ : 10000000
# Whoscall - Caller ID & Block : 10000000
# WhatsCall Free Global Phone Call App & Cheap Calls : 10000000
# WhatsApp Business : 10000000
# WEB.DE Mail : 10000000
# Voxer Walkie Talkie Messenger : 10000000
# TouchPal Keyboard - Fun Emoji & Android Keyboard : 10000000
# Text SMS : 10000000
# Talkray - Free Calls & Texts : 10000000
# Talkatone: Free Texts, Calls & Phone Number : 10000000
# Puffin Web Browser : 10000000
# Psiphon Pro - The Internet Freedom VPN : 10000000
# Portable Wi-Fi hotspot : 10000000
# Orfox: Tor Browser for Android : 10000000
# Opera Mini browser beta : 10000000
# Omlet Chat : 10000000
# Mr. Number-Block calls & spam : 10000000
# Messenger for SMS : 10000000
# MegaFon Dashboard : 10000000
# ICQ — Video Calls & Chat Messenger : 10000000
# Hiya - Caller ID & Block : 10000000
# Hangouts Dialer - Call Phones : 10000000
# GroupMe : 10000000
# Google Voice : 10000000
# Google Allo : 10000000
# Glide - Video Chat Messenger : 10000000
# GO Notifier : 10000000
# GMX Mail : 10000000
# Free WiFi Connect : 10000000
# Free Adblocker Browser - Adblock & Popup Blocker : 10000000
# ExDialer - Dialer & Contacts : 10000000
# Discord - Chat for Gamers : 10000000
# DU Browser—Browse fast & fun : 10000000
# Cricket Visual Voicemail : 10000000
# Contacts+ : 10000000
# Calls Blacklist - Call Blocker : 10000000
# CallApp: Caller ID, Blocker & Phone Call Recorder : 10000000
# Browser 4G : 10000000
# Adblock Browser for Android : 10000000
# AT&T Visual Voicemail : 10000000
# Your Freedom VPN Client : 5000000
# Web Browser & Explorer : 5000000
# Sync.ME – Caller ID & Block : 5000000
# Skype Lite - Free Video Call & Chat : 5000000
# My Vodacom SA : 5000000
# My Tele2 : 5000000
# Microsoft Edge : 5000000
# K-9 Mail : 5000000
# JusTalk - Free Video Calls and Fun Video Chat : 5000000
# Full Screen Caller ID : 5000000
# Ear Agent: Super Hearing : 5000000
# Daum Mail - Next Mail : 5000000
# Chrome Dev : 5000000
# Calls & Text by Mo+ : 5000000
# Caller ID & Call Block - DU Caller : 5000000
# Call Free – Free Call : 5000000
# Call Control - Call Blocker : 5000000
# CM Transfer - Share any files with friends nearby : 5000000
# CIA - Caller ID & Call Blocker : 5000000
# Brave Browser: Fast AdBlocker : 5000000
# Bluetooth Auto Connect : 5000000
# AT&T Call Protect : 5000000
# mysms SMS Text Messaging Sync : 1000000
# mail.com mail : 1000000
# Wi-Fi Auto-connect : 1000000
# Web Browser for Android : 1000000
# WeFi - Free Fast WiFi Connect & Find Wi-Fi Map : 1000000
# Vonage Mobile® Call Video Text : 1000000
# Virtual Walkie Talkie : 1000000
# Video Caller Id : 1000000
# True Contact - Real Caller ID : 1000000
# TracFone My Account : 1000000
# Tiny Call Confirm : 1000000
# Should I Answer? : 1000000
# Seznam.cz : 1000000
# Safest Call Blocker : 1000000
# SW-100.tch by Callstel : 1000000
# RocketDial Dialer & Contacts : 1000000
# PHONE for Google Voice & GTalk : 1000000
# Ninesky Browser : 1000000
# Newton Mail - Email App for Gmail, Outlook, IMAP : 1000000
# My magenta : 1000000
# My Vodafone (GR) : 1000000
# Messaging+ SMS, MMS Free : 1000000
# Lite for Facebook Messenger : 1000000
# InBrowser - Incognito Browsing : 1000000
# Ghostery Privacy Browser : 1000000
# Firefox Focus: The privacy browser : 1000000
# Email TypeApp - Mail App : 1000000
# DW Contacts & Phone & Dialer : 1000000
# ClanPlay: Community and Tools for Gamers : 1000000
# Caller ID + : 1000000
# Call Blocker - Blacklist, SMS Blocker : 1000000
# CB Radio Chat - for friends! : 1000000
# Burner - Free Phone Number : 1000000
# BBMoji - Your personalized BBM Stickers : 1000000
# AntennaPict β : 1000000
# All Email Providers : 1000000
# Adblock Plus for Samsung Internet - Browse safe. : 1000000
# AW - free video calls and chat : 1000000
# AT&T Messages for Tablet : 1000000
# 2ndLine - Second Phone Number : 1000000
# Web Browser : 500000
# U - Webinars, Meetings & Messenger : 500000
# TownWiFi | Wi-Fi Everywhere : 500000
# Talkie - Wi-Fi Calling, Chats, File Sharing : 500000
# SolMail - All-in-One email app : 500000
# LokLok: Draw on a Lock Screen : 500000
# Lightning Web Browser : 500000
# FreedomPop Messaging Phone/SIM : 500000
# BD Data Plan (3G & 4G) : 500000
# WiFi Access Point (hotspot) : 100000
# T-Mobile DIGITS : 100000
# QRZ Assistant : 100000
# Portable Wi-Fi hotspot Free : 100000
# PlacarTv Futebol Ao Vivo : 100000
# Morse Code Reader : 100000
# M star Dialer : 100000
# K-@ Mail - Email App : 100000
# Goodbox - Mega App : 100000
# Everbridge : 100000
# Channel 19 : 100000
# CB On Mobile : 100000
# Baby Monitor AV : 100000
# BT MeetMe with Dolby Voice : 100000
# Antillean Gold Telegram (original version) : 100000
# AZ Browser. Private & Download : 100000
# X Browser : 50000
# N-Com Wizard : 50000
# My BF App : 50000
# IZ2UUF Morse Koch CW : 50000
# HipChat - beta version : 50000
# Free Wi-fi HotspoT : 50000
# BT Messenger : 50000
# BD Internet Packages (Updated) : 50000
# AudioBT: BT audio GPS/SMS/Text : 50000
# 3G DZ Configuration : 50000
# m:go BiH : 10000
# [verify-U] VideoIdent : 10000
# Ring : 10000
# Pocket Prefix Plus : 10000
# Mail1Click - Secure Mail : 10000
# Jazz Wi-Fi : 10000
# Inbox.eu : 10000
# Ham Radio Prefixes : 10000
# Feel Performer : 10000
# Eg Call : 10000
# EZ Wifi Notification : 10000
# Deaf World DW : 10000
# DMR BrandMeister Tool : 10000
# ClanHQ : 10000
# BT One Phone Mobile App : 10000
# BF Browser by Betfilter - Stop Gambling Today! : 10000
# BD Dialer : 10000
# Ad Blocker Turbo - Adblocker Browser : 10000
# Access Point Names : 10000
# /u/app : 10000
# retteMi.ch : 5000
# mail.co.uk Mail : 5000
# love sms good morning : 5000
# Sat-Fi : 5000
# Mircules DX Cluster Lite : 5000
# Learn Morse Code - G0HYN Learn Morse : 5000
# K-9 Material (unofficial) : 5000
# Ham DX Cluster & Spots Finder : 5000
# DM for WhatsApp : 5000
# DM Talk New : 5000
# Council Voting Calculator : 5000
# CS Browser Beta : 5000
# BT One Voice mobile access : 5000
# BD Live Call : 5000
# AK Phone : 5000
# AG Contacts, Lite edition : 5000
# cluster.dk : 1000
# Sat-Fi Voice : 1000
# SMS Sender - sluzba.cz : 1000
# ReadyOp DT : 1000
# FO AIRBUS TLSE : 1000
# FC Browser - Focus Privacy Browser : 1000
# EU Council : 1000
# DM Tracker : 1000
# Call Blocker & Blacklist : 1000
# CS Customizer : 1000
# CS Browser | #1 & BEST BROWSER : 1000
# CQ-Mobile : 1000
# BlueDV AMBE : 1000
# BQ Partners : 1000
# BN MALLORCA Radio : 1000
# BK Chat : 1000
# BH Mail : 1000
# AV Phone : 1000
# AU Call Blocker - Block Unwanted Calls Texts 2018 : 1000
# Traffic signs BD : 500
# Rádio Sol Nascente DF : 500
# Have your say on Europe : 500
# ES-1 : 500
# CW BLE Peripheral Simulator : 500
# CQ-Alert : 500
# Best Auto Call Recorder Free : 500
# ATC Unico BS : 500
# tournaments and more.aj.2 : 100
# chat dz : 100
# [EF]ShoutBox : 100
# Programi podrške EU : 100
# MARKET FO : 100
# Katalogen.ax : 100
# FP Connect : 100
# FO STELIA Méaulte : 100
# FO SODEXO : 100
# FO RCBT : 100
# FO PSA Sept-Fons : 100
# FO OP St-Nazaire : 100
# FO Interim : 100
# FO AIRBUS Nantes : 100
# EP RSS Reader : 100
# EHiN-FH conferenceapp : 100
# DG Card : 100
# Cy Messenger : 100
# Carpooling FH Hagenberg : 100
# CW Bluetooth SPP : 100
# CJ DVD Rentals : 100
# CJ Browser - Fast & Private : 100
# CF Chat: Connecting Friends : 100
# C W Browser : 100
# Bee'ah Employee App : 100
# BV : 100
# Amadeus GR & CY : 100
# Aj.Petra : 100
# Hyundai CX Conference : 50
# DK TEL Dialer : 50
# Cb browser : 50
# BS-Mobile : 50
# AC-BL : 50
# ei : 10
# Oklahoma Ag Co-op Council : 10
# Hlášenírozhlasu.cz : 10
# FP Live : 10
# FNH Payment Info : 10
# FN Web Radio : 10
# Ek IRA : 10
# EO Mumbai : 10
# EJ messenger : 10
# DM - The Offical Messaging App : 10
# DK Browser : 10
# CK Call NEW : 10
# Best Browser BD social networking : 10
# BJ - Confidential : 10
# Test Server SMS FA : 5
# Of the wall Arapaho bk : 5
# BA SALES : 1

# %% [markdown]
# ---> We saw the giants are WhatsApp, Skype, Messenger, Hangounts, Google Chrome and Gmail -  there should not be space to entry in this market

# %%
table_display=[]
for each in play_en_free_cleaned:
    if each[1] == 'VIDEO_PLAYERS':
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        tupples=(installers, each[0])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# YouTube : 1000000000
# Google Play Movies & TV : 1000000000
# MX Player : 500000000
# VivaVideo - Video Editor & Photo Movie : 100000000
# VideoShow-Video Editor, Video Maker, Beauty Camera : 100000000
# VLC for Android : 100000000
# Motorola Gallery : 100000000
# Motorola FM Radio : 100000000
# Dubsmash : 100000000
# Vote for : 50000000
# Vigo Video : 50000000
# VMate : 50000000
# Samsung Video Library : 50000000
# Ringdroid : 50000000
# MiniMovie - Free Video and Slideshow Editor : 50000000
# LIKE – Magic Video Maker & Community : 50000000
# KineMaster – Pro Video Editor : 50000000
# HD Video Downloader : 2018 Best video mate : 50000000
# DU Recorder – Screen Recorder, Video Editor, Live : 50000000
# video player for android : 10000000
# iMediaShare – Photos & Music : 10000000
# YouTube Studio : 10000000
# Video Player All Format : 10000000
# Video Downloader - for Instagram Repost App : 10000000
# Video Downloader : 10000000
# Ustream : 10000000
# Quik – Free Video Editor for photos, clips, music : 10000000
# PowerDirector Video Editor App: 4K, Slow Mo & More : 10000000
# Omlet Arcade - Stream, Meet, Play : 10000000
# Naruto Shippuden - Watch Free! : 10000000
# Music - Mp3 Player : 10000000
# Mobizen Screen Recorder for SAMSUNG : 10000000
# Magisto Video Editor & Maker : 10000000
# Inst Download - Video & Photo : 10000000
# HTC Service － DLNA : 10000000
# HTC Gallery : 10000000
# FrostWire: Torrent Downloader & Music Player : 10000000
# FilmoraGo - Free Video Editor : 10000000
# Code : 10000000
# Cartoon Network App : 10000000
# BitTorrent®- Torrent Downloads : 10000000
# BSPlayer FREE : 10000000
# All Video Downloader : 10000000
# AfreecaTV : 10000000
# AZ Screen Recorder - No Root : 10000000
# YouCut - Video Editor & Video Maker, No Watermark : 5000000
# WiFi Baby Monitor - NannyCam : 5000000
# Video Editor : 5000000
# HTC Service—Video Player : 5000000
# Droid Zap by Motorola : 5000000
# Adobe Premiere Clip : 5000000
# ActionDirector Video Editor - Edit Videos Fast : 5000000
# video player : 1000000
# iSmart DV : 1000000
# iPlayIT for YouTube VR Player : 1000000
# XX HD Video downloader-Free Video Downloader : 1000000
# Vuze Torrent Downloader : 1000000
# Video.Guru - Video Maker : 1000000
# Video Status : 1000000
# Video Editor,Crop Video,Movie Video,Music,Effects : 1000000
# VidPlay : 1000000
# VUE: video editor & camcorder : 1000000
# VPlayer : 1000000
# Tencent Video - Supporting the whole network : 1000000
# SVT Play : 1000000
# Play Tube : 1000000
# OnePlus Gallery : 1000000
# OBJECTIVE : 1000000
# Multiple Videos at Same Time : 1000000
# Mobizen Screen Recorder for LG - Record, Capture : 1000000
# Iqiyi (for tablet) : 1000000
# HD Video Player : 1000000
# HD Video Download for Facebook : 1000000
# HD Movie Video Player : 1000000
# G Guide Program Guide (SOFTBANK EMOBILE WILLCOM version) : 1000000
# Funny videos for whatsapp : 1000000
# EZCast – Cast Media to TV : 1000000
# DU Privacy-hide apps、sms、file : 1000000
# DS video : 1000000
# DS photo : 1000000
# BluTV : 1000000
# BSPlayer ARMv7 VFP CPU support : 1000000
# AndStream - Streaming Download : 1000000
# All Video Downloader 2018 : 1000000
# AX Player -Nougat Video Player : 1000000
# Video Player All Format for Android : 500000
# GoPlus Cam : 500000
# DR TV : 500000
# CJ VLC HD Remote (+ Stream) : 500000
# amazer - Global Kpop Video Community : 100000
# Video Downloader for FB : Video Download with Link : 100000
# Sketch 'n' go : 100000
# Nero AirBurn : 100000
# GoAction : 100000
# Free TV series : 100000
# Ez Screen Recorder (no ad) : 100000
# EZ Web Video Cast | Chromecast : 100000
# ES Audio Player ( Shortcut ) : 100000
# BGCN TV : 100000
# AW Screen Recorder No Root : 100000
# AB Repeat Player : 100000
# dv Prompter : 50000
# bgtime.tv : 50000
# ES-IPTV : 50000
# BR Series : 50000
# AX Video Player : 50000
# ACTIVEON CX & CX GOLD : 50000
# ek tuhi : 10000
# W Box VMS : 10000
# MelifeCam-M : 10000
# HD VideoDownlaoder For Fb : XXVideo Downloader : 10000
# HD Video Player (wmv,avi,mp4,flv,av,mpg,mkv)2017 : 10000
# EZ-SEE : 10000
# EZ Usenet for Easynews® : 10000
# EZ TV Player : 10000
# EML UPnP-AV Control Point : 10000
# Downvids Helper - One touch DW : 10000
# DG Video Editor : 10000
# DG UPnP Player Free : 10000
# Casper Ssinema : 10000
# BS player remote : 10000
# BK News Channel : 10000
# W Box VMS HD : 5000
# Videos downloader for Facebook:fast fb video saver : 5000
# Q-See Plus : 5000
# M-Sight Pro : 5000
# HD Video Player - Video & MP3 Player | AV Player | : 5000
# Furrion ES Control : 5000
# EF Sidekick : 5000
# DZ Popup Video Player : 5000
# DV Lottery Photo : 5000
# BR Video Player : 5000
# BG video - floating video - background video : 5000
# Ay : 5000
# A-B repeater : 5000
# 4K VIDEO PLAYER ULTRA HD : 5000
# Music for Youtube - Tube Music BG, Red+ : 1000
# Movie Downloader Torrent : Az Torrent : 1000
# EZ game screen recorder with audio 1080P : 1000
# CINE BR : 1000
# BZ Langenthaler Tagblatt : 1000
# BC iptv player : 1000
# Ay Sabz Gunbad Waly : 1000
# AV-IPTV : 1000
# YourTube Video Views BG : 500
# Video Wallpaper Show : 500
# DG Screen Recorder : 500
# CX Monthly Tech News : 500
# CJ Camcorder : 500
# A-Z Screen Recorder - : 500
# List iptv FR : 100
# EC MANAGER : 100
# Bx-WiFi-GI : 100
# Bc Vod : 100
# BG MUSIC PLAYER - MUSIC PLAYER : 100
# AK Lodi Films : 100
# AJ Player : 100
# CI Stream : 10
# Art of F J Taylor : 10

# %% [markdown]
# ---> We saw the giants are Youtube, Google play movies and then MXplayer - there should not be space to entry in this market

# %%
table_display=[]
for each in play_en_free_cleaned:
    if each[1] == 'SOCIAL':
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        tupples=(installers, each[0])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Instagram : 1000000000
# Google+ : 1000000000
# Facebook : 1000000000
# Snapchat : 500000000
# Facebook Lite : 500000000
# VK : 100000000
# Tumblr : 100000000
# Tik Tok - including musical.ly : 100000000
# Tango - Live Video Broadcast : 100000000
# Pinterest : 100000000
# LinkedIn : 100000000
# Badoo - Free Chat & Dating App : 100000000
# BIGO LIVE - Live Stream : 100000000
# ooVoo Video Calls, Messaging & Stories : 50000000
# Zello PTT Walkie Talkie : 50000000
# SKOUT - Meet, Chat, Go Live : 50000000
# POF Free Dating App : 50000000
# MeetMe: Chat & Meet New People : 50000000
# textPlus: Free Text & Calls : 10000000
# magicApp Calling & Messaging : 10000000
# YouNow: Live Stream Video Chat : 10000000
# We Heart It : 10000000
# Waplog - Free Chat, Dating App, Meet Singles : 10000000
# TextNow - free text + calls : 10000000
# Text free - Free Text + Call : 10000000
# Text Me: Text Free, Call Free, Second Phone Number : 10000000
# Tapatalk - 100,000+ Forums : 10000000
# Tagged - Meet, Chat & Dating : 10000000
# SayHi Chat, Meet New People : 10000000
# Quora : 10000000
# Phone Tracker : Family Locator : 10000000
# Periscope - Live Video : 10000000
# Path : 10000000
# Mico- Stranger Chat Random video Chat, Live, Meet : 10000000
# Messenger Messenger : 10000000
# Messenger : 10000000
# Messages, Text and Video Chat for Messenger : 10000000
# LiveMe - Video chat, new friends, and make money : 10000000
# Legend - Animate Text in Video : 10000000
# LOVOO : 10000000
# Kate Mobile for VK : 10000000
# Jaumo Dating, Flirt & Live Video : 10000000
# HTC Social Plugin - Facebook : 10000000
# Grindr - Gay chat : 10000000
# Free phone calls, free texting SMS on free number : 10000000
# Find My Friends : 10000000
# Dating App, Flirt & Chat : W-Match : 10000000
# Amino: Communities and Chats : 10000000
# Who Viewed My Facebook Profile - Stalkers Visitors : 5000000
# Whisper : 5000000
# Web Browser & Fast Explorer : 5000000
# VidStatus app - Status Videos & Status Downloader : 5000000
# Timehop : 5000000
# Text Free: WiFi Calling App : 5000000
# Telegram X : 5000000
# SPARK - Live random video chat & meet new people : 5000000
# Nextdoor - Local neighborhood news & classifieds : 5000000
# Meetup : 5000000
# Meet – Talk to Strangers Using Random Video Chat : 5000000
# Instachat 😜 : 5000000
# Hornet - Gay Social Network : 5000000
# Hide Something - Photo, Video : 5000000
# HOLLA Live: Meet New People via Random Video Chat : 5000000
# FunForMobile Ringtones & Chat : 5000000
# Frim: get new friends on local chat rooms : 5000000
# Fame Boom for Real Followers, Likes : 5000000
# Blogger : 5000000
# 💘 WhatsLov: Smileys of love, stickers and GIF : 1000000
# pixiv : 1000000
# Wishbone - Compare Anything : 1000000
# VMate Lite - Funny Short Videos Social Network : 1000000
# U LIVE – Video Chat & Stream : 1000000
# TwitCasting Live : 1000000
# The Messenger App : 1000000
# Stickers for Facebook : 1000000
# Snaappy – 3D fun AR core communication platform : 1000000
# Moment : 1000000
# MobilePatrol Public Safety App : 1000000
# Messenger Pro : 1000000
# Love Sticker : 1000000
# Love Images : 1000000
# Lesbian Chat & Dating - SPICY : 1000000
# Jodel - The Hyperlocal App : 1000000
# GUYZ - Gay Chat & Gay Dating : 1000000
# Frontback - Social Photos : 1000000
# Friendly for Facebook : 1000000
# Free Messages, Video, Chat,Text for Messenger Plus : 1000000
# FollowMeter for Instagram : 1000000
# Fiesta by Tango - Find, Meet and Make New Friends : 1000000
# Faster for Facebook Lite : 1000000
# Family GPS tracker KidControl + GPS by SMS Locator : 1000000
# Facebook Local : 1000000
# Facebook Creator : 1000000
# EZ Video Download for Facebook : 1000000
# Couple - Relationship App : 1000000
# Banjo : 1000000
# BOO! - Next Generation Messenger : 1000000
# B-Messenger Video Chat : 1000000
# All Social Networks : 1000000
# +Download 4 Instagram Twitter : 1000000
# Web Browser ( Fast & Secure Web Explorer) : 500000
# Verdad o Reto : 500000
# Swift for Facebook Lite : 500000
# Stream - Live Video Community : 500000
# Qeek for Instagram - Zoom profile insta DP : 500000
# Puffin for Facebook : 500000
# Profile Tracker - Who Viewed My Facebook Profile : 500000
# Pink Color for Facebook : 500000
# Mirrativ: Live Stream Any App : 500000
# Greeting Cards & Wishes : 500000
# Gayvox - Gay Lesbian Bi Dating : 500000
# Fake Chat (Direct Message) : 500000
# Daddyhunt: Gay Dating : 500000
# Bloglovin' : 500000
# uCiC- Videos and Photos on demand : 100000
# YAY - TBH : 100000
# What U See : 100000
# The Video Messenger App : 100000
# Social network all in one 2018 : 100000
# See U - Random video chat, video chat : 100000
# Phoenix - Facebook & Messenger : 100000
# Patook - make platonic friends : 100000
# Meet U - Get Friends for Snapchat, Kik & Instagram : 100000
# MB Notifications for FB (Free) : 100000
# KPOP Amino for K-Pop Entertainment : 100000
# KDRAMA Amino for K-Drama Fans : 100000
# FutureNet your social app : 100000
# Fr Daoud Lamei : 100000
# Faster Social for Facebook : 100000
# Dr. B.R.Ambedkar : 100000
# Dr B R Ambedkar (Jai Bhim) : 100000
# Dating.dk : 100000
# DP and Status for WhatsApp 2018 : 100000
# Chat For Strangers - Video Chat : 100000
# Blogaway for Android (Blogger) : 100000
# Undertale AU Amino : 50000
# Rande.cz : 50000
# Hashtags For Likes.co : 50000
# Golden telegram : 50000
# FCB Connect - FC Barcelona : 50000
# Equestria Amino for MLP : 50000
# EXO-L Amino for EXO Fans : 50000
# CP Dialer : 50000
# BT Dating -Find your match, help cupid, be social : 50000
# Anime et Manga Amino en Français : 50000
# Unlimited Group Links - Whatsapp, FB, Telegram : 10000
# U-Report : 10000
# Stickers for Imo, fb, whatsapp : 10000
# Share G - Images Sharing - Wallpapers App : 10000
# Mini for Facebook lite : 10000
# Mali J : 10000
# Lite Messenger for Facebook Lite : 10000
# Jamaa Amino for Animal Jam : 10000
# Ek Maratha : 10000
# Eddsworld Amino : 10000
# Digi-TV.ch : 10000
# Daily Murli Saar Widget : 10000
# DM Me - Chat : 10000
# Cyprus Police : 10000
# Best DP and Status : 10000
# BT Communicator : 10000
# BK Traffic Control cum Chart : 10000
# Au Pair : 10000
# funny Image Comments for FB : 5000
# TNEB Bill Online Payment (Tamil) : 5000
# TN e Sevai TN EB Bill Patta Citta EC Birth All Hub : 5000
# Profile Pictures and DP for Whatsapp : 5000
# Instant DP Downloader for Instagram : 5000
# Dp for Facebook : 5000
# Dp For Whatsapp : 5000
# DP Display Pictures Life Quotes Motivational GM : 5000
# DM for IG 😘 - Image & Video Saver for Instagram : 5000
# DB Event App : 5000
# Check Your Visitors on FB ? : 5000
# signály.cz : 1000
# eChallan Andhra Pradesh (AP) : 1000
# Zdravei.BG : 1000
# V Bucks ProTips New : 1000
# TN EC Online New : 1000
# Students.ch : 1000
# Sabka Malik Ek Sai : 1000
# Noticias DF : 1000
# Media Sosial TNI AU : 1000
# Join R, Community Engagement : 1000
# H letter images : 1000
# European Solidarity Corps : 1000
# DW Streaming : 1000
# DC Comics Amino : 1000
# CG Districts : 1000
# Black Social : 1000
# BR Chat Bot : 1000
# BGKontakti Vienna BG Kontakti : 1000
# BGKontakti Bayern BG Kontakti : 1000
# BG LINKED (BGLINKED) : 1000
# Auto DM for Twitter 🔥 : 1000
# Alarm.fo – choose your info : 1000
# iCard BD Plus : 500
# Downloader plus for FB : 500
# DK Murali : 500
# DF BugMeNot : 500
# Br Browser : 500
# BGKontakti London BG Kontakti : 500
# i-share AF/KLM (AFKL ishare) : 100
# TN Patta /Chitta /EC New : 100
# Rejoin Your Ex : 100
# Naruto & Boruto FR : 100
# Myjob@BM : 100
# Movement BE : 100
# Message AI - Write Better Messages (Free) : 100
# GirlTalk.dk : 100
# Frases Cristianas de Esperanza y Fe : 100
# Evasion.bz : 100
# Eternal Light AG : 100
# Discípulos em BH : 100
# DV Statistics : 100
# DM Storage (for twitter) : 100
# CJ Gospel Hour : 100
# Alumni BJ : 100
# UP EB Bill Payment & Details : 50
# FB Advanced Search : 50
# EG Way Life : 50
# Coupe Adhémar EY 2017 : 50
# quran-DZ : 10
# bm-Events : 10
# Reisedealz.eu : 10
# Otto DM : 10
# News Dz : 10
# Hum Ek Hain 2.02 : 10
# EO RAIPUR : 10
# DN Blog : 10
# BA 3 Banjarmasin : 10
# CB Heroes : 5
# C.P. CERVANTES (TOBARRA) : 5
# BH Connect : 1
# Amleen Ey : 1
# Pekalongan CJ : 0

# %% [markdown]
# ---> We saw the giants are Instagram, Google+, Facebook and Snapchat - there should not be space to entry in this market

# %%
table_display=[]
for each in play_en_free_cleaned:
    if each[1] == 'PHOTOGRAPHY':
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        tupples=(installers, each[0])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Google Photos : 1000000000
# Z Camera - Photo Editor, Beauty Selfie, Collage : 100000000
# YouCam Perfect - Selfie Photo Editor : 100000000
# YouCam Makeup - Magic Selfie Makeovers : 100000000
# Sweet Selfie - selfie camera, beauty cam, photo edit : 100000000
# S Photo Editor - Collage Maker , Photo Collage : 100000000
# Retrica : 100000000
# PicsArt Photo Studio: Collage Maker & Pic Editor : 100000000
# PhotoGrid: Video & Pic Collage Maker, Photo Editor : 100000000
# Photo Editor Pro : 100000000
# Photo Editor Collage Maker Pro : 100000000
# Photo Collage Editor : 100000000
# LINE Camera - Photo editor : 100000000
# Cymera Camera- Photo Editor, Filter,Collage,Layout : 100000000
# Candy Camera - selfie, beauty camera, photo editor : 100000000
# Camera360: Selfie Photo Editor with Funny Sticker : 100000000
# BeautyPlus - Easy Photo Editor & Selfie Camera : 100000000
# B612 - Beauty & Filter Camera : 100000000
# AR effect : 100000000
# Video Editor Music,Cut,No Crop : 50000000
# VSCO : 50000000
# Square InPic - Photo Editor & Collage Maker : 50000000
# Snapseed : 50000000
# Selfie Camera - Photo Editor & Filter & Sticker : 50000000
# SNOW - AR Camera : 50000000
# Pixlr – Free Photo Editor : 50000000
# Pic Collage - Photo Editor : 50000000
# PhotoWonder: Pro Beauty Photo Editor Collage Maker : 50000000
# Photo Lab Picture Editor: face effects, art frames : 50000000
# Photo Effects Pro : 50000000
# Photo Editor by Aviary : 50000000
# Photo Editor Selfie Camera Filter & Mirror Image : 50000000
# Motorola Camera : 50000000
# MomentCam Cartoons & Stickers : 50000000
# MakeupPlus - Your Own Virtual Makeup Artist : 50000000
# Keepsafe Photo Vault: Hide Private Photos & Videos : 50000000
# InstaSize Photo Filters & Collage Editor : 50000000
# InstaBeauty -Makeup Selfie Cam : 50000000
# Boomerang from Instagram : 50000000
# Adobe Photoshop Express:Photo Editor Collage Maker : 50000000
# ASUS Gallery : 50000000
# Wondershare PowerCam : 10000000
# Sweet Snap - live filter, Selfie photo edit : 10000000
# Sweet Camera - Selfie Filters, Beauty Camera : 10000000
# Scoompa Video - Slideshow Maker and Video Editor : 10000000
# RetroSelfie - Selfie Editor : 10000000
# Retro Camera : 10000000
# QuickPic - Photo Gallery with Google Drive Support : 10000000
# Pixlr-o-matic : 10000000
# PixelLab - Text on pictures : 10000000
# PhotoScan by Google Photos : 10000000
# PhotoLayers〜Superimpose,Eraser : 10000000
# PhotoFunia : 10000000
# PhotoDirector Photo Editor App : 10000000
# Photo Studio : 10000000
# Photo Mixer : 10000000
# Photo Frames : 10000000
# Photo Frame : 10000000
# Photo Editor by BeFunky : 10000000
# Photo Editor : 10000000
# Photo Collage Maker : 10000000
# Photo Collage - Layout Editor : 10000000
# Photo Collage - InstaMag : 10000000
# Phonto - Text on Photos : 10000000
# PIP Selfie Camera Photo Editor : 10000000
# Open Camera : 10000000
# No Crop & Square for Instagram : 10000000
# My Photo Keyboard : 10000000
# Mirror Photo:Editor Collage (HD) : 10000000
# Meitu – Beauty Cam, Easy Photo Editor : 10000000
# Love Collage - Photo Editor : 10000000
# LightX Photo Editor & Photo Effects : 10000000
# HD Camera for Android : 10000000
# HD Camera Ultra : 10000000
# GoPro (formerly Capture) : 10000000
# Free Slideshow Maker & Video Editor : 10000000
# Fotor Photo Editor - Photo Collage & Photo Effects : 10000000
# Font Studio- Photo Texts Image : 10000000
# Flickr : 10000000
# Facejjang : 10000000
# FaceApp : 10000000
# Face Filter, Selfie Editor - Sweet Camera : 10000000
# EyeEm - Camera & Photo Filter : 10000000
# Color Touch Effects : 10000000
# Candy selfie - photo editor, live filter camera : 10000000
# Cameringo Lite. Filters Camera : 10000000
# Camera360 Lite - Selfie Camera : 10000000
# Camera for Android : 10000000
# Camera MX - Free Photo & Video Camera : 10000000
# Camera FV-5 Lite : 10000000
# Bokeh (Background defocus) : 10000000
# Blur Image Background : 10000000
# Bestie - Camera360 Selfie : 10000000
# Beauty Makeup Snappy Collage Photo Editor - Lidow : 10000000
# Background Eraser : 10000000
# AfterFocus : 10000000
# ASUS PixelMaster Camera : 10000000
# A+ Gallery - Photos & Videos : 10000000
# Visage Lab – face retouch : 5000000
# Sweet Camera : 5000000
# SuperPhoto - Effects & Filters : 5000000
# Story Saver for Instagram : 5000000
# Silent Camera [High Quality] : 5000000
# Shutterfly: Free Prints, Photo Books, Cards, Gifts : 5000000
# Pretty Makeup, Beauty Photo Editor & Snappy Camera : 5000000
# Pixgram- video photo slideshow : 5000000
# Picture Grid Builder : 5000000
# Photo Editor- : 5000000
# Muzy - Share photos & collages : 5000000
# Moto Photo Editor : 5000000
# MIX by Camera360 : 5000000
# Huji Cam : 5000000
# High-Speed Camera (GIF,Burst) : 5000000
# HD Camera - Best Cam with filters & panorama : 5000000
# HD Camera : 5000000
# Ghost In Photo : 5000000
# Collage&Add Stickers papelook : 5000000
# Change photo background : 5000000
# Camera ZOOM FX - FREE : 5000000
# Blur Image Background Editor (Blur Photo Editor) : 5000000
# Blur Image - DSLR focus effect : 5000000
# Adobe Photoshop Fix : 5000000
# Adobe Illustrator Draw : 5000000
# A Better Camera : 5000000
# love : 1000000
# XDV : 1000000
# Waterfall Photo Frames : 1000000
# Video Maker with Photo and Music : 1000000
# Unicorn Photo : 1000000
# Ultimate Background Eraser : 1000000
# TouchNote: Cards & Gifts : 1000000
# Thumbnail Maker : 1000000
# Snapfish : 1000000
# Snap Cat Face Camera : 1000000
# Six Pack Abs Photo Editor : 1000000
# Selfie Photo Editor : 1000000
# Selfie Camera: Beauty Camera, Photo Editor,Collage : 1000000
# Samsung SMART CAMERA App : 1000000
# Pic Stitch - #1 Collage Maker : 1000000
# Phogy, 3D Camera : 1000000
# Pencil Photo Sketch-Sketching Drawing Photo Editor : 1000000
# Night Photo Frame : 1000000
# Mega Photo : 1000000
# Makeup Photo Editor: Makeup Camera & Makeup Editor : 1000000
# Makeup Editor -Beauty Photo Editor & Selfie Camera : 1000000
# LightMeter Free : 1000000
# LALALAB prints your photos, photobooks and magnets : 1000000
# Kids Photo Frames : 1000000
# KVAD Camera +: Selfie, Photo Filter, Grids : 1000000
# InstaCam - Camera for Selfie : 1000000
# Insave-Download for Instagram : 1000000
# Hypocam : 1000000
# HD Camera Pro for Android : 1000000
# HD Camera - silent shutter : 1000000
# HD Camera - Quick Snap Photo & Video : 1000000
# FreePrints – Free Photos Delivered : 1000000
# Footej Camera : 1000000
# FilterGrid - Cam&Photo Editor : 1000000
# F-Stop Gallery : 1000000
# Ez iCam : 1000000
# DSLR Camera Hd Ultra Professional : 1000000
# Cut Out : Background Eraser and background changer : 1000000
# Canon CameraWindow : 1000000
# Camera51 - a smarter camera : 1000000
# Camera Pro : 1000000
# Blur : 1000000
# Beauty Makeup – Photo Makeover : 1000000
# BQ Camera : 1000000
# Auto Background Changer : 1000000
# Afterlight : 1000000
# Add Watermark Free : 1000000
# Add Text To Photo : 1000000
# easyFocus : 500000
# camera zoom moon : 500000
# U Camera : Phone 6s OS 9 style : 500000
# Sweet Snap Lite - live filter, Selfie photo editor : 500000
# How Do I Look : 500000
# Groovebook Photo Books & Gifts : 500000
# Garden Photo Frames - Garden Photo Editor : 500000
# DU GIF Maker: GIF Maker, Video to GIF & GIF Editor : 500000
# Brica BPRO5 AE : 500000
# Blurfoto : Auto blur photo background & DSLR focus : 500000
# Background Changer & Eraser : 500000
# BT Camera : 500000
# ez Share Android app : 100000
# V.360° Camera : 100000
# SportLook : 100000
# Picai - Smart AI Camera : 100000
# Photo frame : 100000
# Gold Teeth Photo Editor : 100000
# Fifa World Cup 2018: Photo Frame Editor & DP Maker : 100000
# DU Collage Maker - Photo Collage & Grid & Layout : 100000
# DSLR Photography Training apps : 100000
# DP Maker : 100000
# DP Creator for WhatsApp : 100000
# Cover Camera for FB : 100000
# Camera V7 24 Megapixel : 100000
# Black & White Camera - Lovely BW : 100000
# B Tiff Viewer : 100000
# AZ Camera - Manual Pro Cam : 100000
# 4K Ultra Camera : 100000
# 24 megapixel hd camera : 100000
# Wifi Action Camera : 50000
# Moony Lab - Print Photos, Books & Magnets ™ : 50000
# DV Lottery Photo Tool : 50000
# DP Status 2017 : 50000
# BlitzWolf Shutter - BW Shutter : 50000
# B&W Photo Filter Editor : 50000
# Z Camera : 10000
# Square DP For Whatsapp : 10000
# Profile w/o crop for Telegram : 10000
# Night Camera Blur Effect : 10000
# Leica Q : 10000
# FN Cam : 10000
# FH WiFiCam : 10000
# DSLR camera - Auto Focus and Blur Professional : 10000
# DP Photo Editor : 10000
# DF Night Selfies : 10000
# DENVER ACTION CAM 3 : 10000
# Be Fabulous PHOTO BOOTH : 10000
# BL 1-Click Camera - Free : 10000
# Insta Square Profile DP : 5000
# FL Drone 2 : 5000
# DP Editor : 5000
# CB Edits PNG & CB Backgrounds : 5000
# Photo Editor - BPhoto : 1000
# Photo BG Changer : 1000
# PIP-Camera FN Photo Effect : 1000
# Magical Insta DP : 1000
# Live DV : 1000
# Light Meter - EV : 1000
# Leica CL : 1000
# FB Photographie : 1000
# Dp For FB : 1000
# DV-4036 by Somikon : 1000
# DS-L4 Viewer : 1000
# BK Photography : 1000
# Auto Dslr Photo Effect : Auto Focus Effect : 1000
# All Types DP & Status Maker : 1000
# AEE AP : 1000
# Selfie With Champion AJ Style : 500
# DC-014 : 500
# CB Hair Png - New Hair Png For CB Editing : 500
# BC Camera : 500
# AI Image Recognizer (beta) : 500
# Wallpaper.cz : 100
# LC-DB-LITE : 100
# FD Fotografia : 100
# DV KING 4K : 100
# DV KING : 100
# CG Prints : 100
# CB VIDEO VISION : 100
# Blender BG - Photo Blend With Background : 100
# BL Portfolio : 100
# Analog BW - Camera filter effect foto film retouch : 100
# AJ Cam : 100
# A.J. Styles HD Wallpapers 2018 : 100
# Touch DV : 50
# Displaying You VR : 50
# i am EB : 10
# BG Editor : 5

# %% [markdown]
# --> We have one big giant - Google Photos - but then we have market split for many apps- which is not so interesting for us

# %%
table_display=[]
for each in play_en_free_cleaned:
    if each[1] == 'PRODUCTIVITY':
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        tupples=(installers, each[0])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Google Drive : 1000000000
# Microsoft Word : 500000000
# Google Calendar : 500000000
# Dropbox : 500000000
# Cloud Print : 500000000
# WPS Office - Word, Docs, PDF, Note, Slide & Sheet : 100000000
# SwiftKey Keyboard : 100000000
# Samsung Notes : 100000000
# Microsoft PowerPoint : 100000000
# Microsoft Outlook : 100000000
# Microsoft OneNote : 100000000
# Microsoft OneDrive : 100000000
# Microsoft Excel : 100000000
# Google Slides : 100000000
# Google Sheets : 100000000
# Google Keep : 100000000
# Google Docs : 100000000
# Evernote – Organizer, Planner for Notes & Memos : 100000000
# ES File Explorer File Manager : 100000000
# ColorNote Notepad Notes : 100000000
# CamScanner - Phone PDF Creator : 100000000
# Adobe Acrobat Reader : 100000000
# myAT&T : 50000000
# Verizon Cloud : 50000000
# QR Droid : 50000000
# My Airtel-Online Recharge, Pay Bill, Wallet, UPI : 50000000
# Mobizen Screen Recorder - Record, Capture, Edit : 50000000
# MEGA : 50000000
# File Browser by Astro (File Manager) : 50000000
# Do It Later: Tasks & To-Dos : 50000000
# Calculator - unit converter : 50000000
# Alarm Clock: Stopwatch & Timer : 50000000
# Advanced Task Killer : 50000000
# iTranslate Translator & Dictionary : 10000000
# aCalendar - Android Phone : 10000000
# Wunderlist: To-Do List & Tasks : 10000000
# U+Box : 10000000
# Todoist: To-do lists for task management & errands : 10000000
# S Note : 10000000
# QR Scanner & Barcode Scanner 2018 : 10000000
# Polaris Office - Word, Docs, Sheets, Slide, PDF : 10000000
# Notepad & To do list : 10000000
# Notepad : 10000000
# NQ Mobile Security & Antivirus : 10000000
# MyVodafone (India) - Online Recharge & Pay Bills : 10000000
# Mobile Security: Antivirus, Web Scan & App Lock : 10000000
# Mobile Security & Antivirus : 10000000
# Metro name iD : 10000000
# LOCX Applock Lock Apps & Photo : 10000000
# Keeper: Free Password Manager & Secure Vault : 10000000
# Jorte Calendar & Organizer : 10000000
# HTC Mail : 10000000
# HTC File Manager : 10000000
# HTC Calendar : 10000000
# Google PDF Viewer : 10000000
# Google Assistant : 10000000
# Fake Call - Fake Caller ID : 10000000
# Easy Voice Recorder : 10000000
# Chrome Beta : 10000000
# CM FILE MANAGER HD : 10000000
# AutoCAD - DWG Viewer & Editor : 10000000
# Any.do: To-do list, Calendar, Reminders & Planner : 10000000
# AndroZip™ FREE File Manager : 10000000
# All-In-One Toolbox: Cleaner, Booster, App Manager : 10000000
# AVG Cleaner – Speed, Battery & Memory Booster : 10000000
# AT&T Mobile Transfer : 10000000
# ASUS SuperNote : 10000000
# ASUS Quick Memo : 10000000
# ASUS Calling Screen : 10000000
# APUS Booster - Space Cleaner & Booster : 10000000
# lifebox : 5000000
# Yandex.Disk : 5000000
# Ultimate Notepad : 5000000
# Trello : 5000000
# To Do List : 5000000
# The Maner : 5000000
# PDF Viewer & Book Reader : 5000000
# Note Everything : 5000000
# My Claro Peru : 5000000
# Microsoft Translator : 5000000
# MediaFire : 5000000
# Keep My Notes - Notepad & Memo : 5000000
# Ginger Keyboard - Emoji, GIFs, Themes & Games : 5000000
# G Cloud Backup : 5000000
# EBookDroid - PDF & DJVU Reader : 5000000
# DigiCal Calendar Agenda : 5000000
# Content Transfer : 5000000
# Clean My Android : 5000000
# Calendar Widget Month + Agenda : 5000000
# Business Calendar 2 : 5000000
# Archos File Manager : 5000000
# pCloud: Free Cloud Storage : 1000000
# e-Boks.dk : 1000000
# Ultimate Chest Tracker : 1000000
# Today Calendar 2017 : 1000000
# To-Do List Widget : 1000000
# To-Do Calendar Planner : 1000000
# To Do Reminder with Alarm : 1000000
# Time Recording - Timesheet App : 1000000
# TickTick: To Do List with Reminder, Day Planner : 1000000
# S’more - Earn Cash Rewards : 1000000
# SugarSync : 1000000
# Sticky Note + : Sync Notes : 1000000
# Squid - Take Notes & Markup PDFs : 1000000
# Solid Explorer File Manager : 1000000
# Solid Explorer Classic : 1000000
# Smart File Manager : 1000000
# Simple Notepad : 1000000
# Security & Privacy : 1000000
# Resume Free : 1000000
# Pushbullet - SMS on PC : 1000000
# Power Booster - Junk Cleaner & CPU Cooler & Boost : 1000000
# Planner Pro-Personal Organizer : 1000000
# Phone Clean Best Speed Booster : 1000000
# NoteToDo. Notes. To do list : 1000000
# New Calendar : 1000000
# Můj T-Mobile Business : 1000000
# MyMTN : 1000000
# Multiling O Keyboard + emoji : 1000000
# Microsoft To-Do: List, Task & Reminder : 1000000
# Mahalaxmi Dindarshika 2018 : 1000000
# Lyra Virtual Assistant : 1000000
# Loop - Habit Tracker : 1000000
# JotterPad - Writer, Screenplay, Novel : 1000000
# IFTTT : 1000000
# Hacker's Keyboard : 1000000
# Google AdSense : 1000000
# Extreme- Personal Voice Assistant : 1000000
# Epson iProjection : 1000000
# Emoji Android L Keyboard : 1000000
# EX File Explorer File Manager : 1000000
# ES Material Theme for Pro : 1000000
# Do it (Tomorrow) : 1000000
# Dashlane Free Password Manager : 1000000
# DS file : 1000000
# Cozi Family Organizer : 1000000
# Chrome Canary (Unstable) : 1000000
# Chelsea FC Official Keyboard : 1000000
# Calendar+ Schedule Planner App : 1000000
# Cal - Google Calendar + Widget : 1000000
# CY Security Antivirus Cleaner : 1000000
# Avast Wi-Fi Finder : 1000000
# Amazon Drive : 1000000
# Adobe Fill & Sign: Easy PDF Form Filler : 1000000
# Adblock Fast : 1000000
# ALL-IN-ONE PACKAGE TRACKING : 1000000
# AL Voice Recorder : 1000000
# Ultimate Calculator for CR : 500000
# Time Planner - Schedule, To-Do List, Time Tracker : 500000
# T-Mobile Content Transfer : 500000
# Q Link Wireless Zone : 500000
# Planning Center Services : 500000
# Official QR Code® Reader "Q" : 500000
# My Effectiveness: To do, Tasks : 500000
# Memory Helper - To do list, Notepad, Notes, Memo : 500000
# ES Holo Theme for Pro : 500000
# DS cam : 500000
# Ad Detect Plugin - Handy Tool : 500000
# A-Z App Store : 500000
# 7 Weeks - Habit & Goal Tracker : 500000
# cm, mm to inch, feet converter tool : 100000
# Unclouded - Cloud Manager : 100000
# Total AV : 100000
# TIMBER AD FILTER - Very useful ad block app : 100000
# Synology Drive : 100000
# Resume Builder and CV maker app : 100000
# Pocket RxTx Free : 100000
# MyLifeOrganized: To-Do List : 100000
# Inch/cm/Foot Conversion : 100000
# Ike - To-Do List, Task List : 100000
# IQ Test : 100000
# IDM for Facebook ★ Downloader : 100000
# IDM Internet Download Manager : 100000
# Goal Meter: Goal Tracker, Habit Changer,To-Do List : 100000
# Future Cloud : 100000
# Friday: Smart Personal Assistant : 100000
# File Explorer : 100000
# Exército Brasileiro : 100000
# EZ Switch Widget : 100000
# EZ File Manager(Root Explorer) : 100000
# ES Disk Analyzer - Storage Space : 100000
# Dz Dinars Numbers to letters : 100000
# Dr.Android Repair Master 2017 : 100000
# Download Manager Pro FREE : 100000
# Do Not Disturb : 100000
# DS note : 100000
# Clean My House – Chore To Do List, Task Scheduler : 100000
# Calculator L : 100000
# Bits Watch Face : 100000
# Best Applock - Locker & No Ads : 100000
# 2Do - Reminders, To-do List & Notes : 100000
# WiFi-o-Matic : 50000
# WFVS 2018 | WhatApp Full Video Status & Downloader : 50000
# U Assist - Screen Mirroring & Sharing App : 50000
# To-do list : 50000
# Safe Notes - Secure Ad-free notepad : 50000
# SH Script Runner : 50000
# Numbers Into Words : 50000
# My C Spire : 50000
# MultiMessage for FB Messenger : 50000
# Inputting Plus: Ctrl + Z/F/C/V : 50000
# EZ Display : 50000
# ESLock File Recovery Lite : 50000
# CTRL-F - Search the real world : 50000
# BJ Memo Widget : 50000
# Add-On: Alcatel (h) : 50000
# ai.Bot Box : 10000
# Wi-Fi Networks : 10000
# Trimble DL : 10000
# Trimble Ag Mobile : 10000
# Tap N Pay : 10000
# Solar CT PV System Power : 10000
# Remote Control For All AC - Universal Remote : 10000
# N Files - File Manager & Explorer : 10000
# Mix Tank – Tank Mixing Ag App : 10000
# Larry H Miller Automotive : 10000
# Eurostat Country Profiles : 10000
# Electricity Bill Calculator BD : 10000
# EZ Inspections : 10000
# EC Taximeter : 10000
# DG Report Reminder : 10000
# Curriculum Vitae - Resume CV : 10000
# CD Library : 10000
# Alt-C : 10000
# Turbo AI™ - Personal assistant : 5000
# Resume & CV Creator by Desygner : 5000
# R-net for Android : 5000
# Mind Map AR, Augmented Reality ARCore Mind Mapping : 5000
# EU Economy : 5000
# ESS Mobile for AE : 5000
# CG - Calendars Add-On : 5000
# Bomb and Nade Timer for CS:GO : 5000
# BA Calculator : 5000
# Air Conditioner Maintenance : 5000
# Add-On: bq (a) : 5000
# AP ENPS Mobile : 5000
# Simple EV Calc : 1000
# Sai Baba - Sabka Malik Ek : 1000
# Safe Wi-Fi : 1000
# Puck AI Personal Assistant Robot : 1000
# Professional AV Solution & Products information : 1000
# New Holland Agriculture T5 EC : 1000
# My CU - Caucasus University : 1000
# Krypton by krypt.co : 1000
# Fayr - Co-Parenting Simplified : 1000
# FQ METER : 1000
# FL House : 1000
# EZ Notes Lite : 1000
# EF Calculator : 1000
# DS-20000S : 1000
# DG Phone Call Task Switcher : 1000
# DB Manager : 1000
# Commission Manager : 1000
# CircleCI Viewer : 1000
# Charlotte County, FL : 1000
# Calendars (En, Bn, Ar) : 1000
# CG - Conference Call Add-On : 1000
# CA World '17 : 1000
# BG+Phone Backup : 1000
# BD Field Force : 1000
# BD Attendance : 1000
# Ag PhD Soils : 1000
# Add-On: bq (c) : 1000
# Add-On: bq (b) : 1000
# AI Sight : 1000
# Tips Microsoft Dynamics Ax : 500
# Q Actions - Digital Assistant : 500
# IP address BW : 500
# Florida Cooling Supply HVAC : 500
# Fast Notes FJ : 500
# Ek Vote : 500
# EY Events Switzerland : 500
# EY ATL Fuel Calculator : 500
# DT Manager : 500
# DN Events : 500
# CP Connect 2.0 : 500
# CJ Wilson's ZoomZoomnation : 500
# BZ Dealer : 500
# iReadMe : 100
# ec-Work : 100
# eG Monitor : 100
# Town of Princeton, BC : 100
# Tips & Tricks Dynamics AX 365 : 100
# Thistletown CI : 100
# Somos CG : 100
# SCS eC : 100
# RoutePlan.cz : 100
# Register.ca Mobile : 100
# MiAI (Artificial Intelligence) Assistant : 100
# Mat|r viewer : 100
# K-App Mitarbeiter Galeria Kaufhof : 100
# J. Polep Plus Mobile : 100
# Fort Myers FL : 100
# ES Billing System (Offline App) : 100
# EP Home Energy Hub : 100
# EG : 100
# EF Staff : 100
# DG Users : 100
# DF-Server Mobile : 100
# Cx Wize : 100
# CJ'S TIRE AND AUTO INC. : 100
# CI Time : 100
# CI Remote for Go : 100
# CI CAFETERIAS UBER : 100
# Builder (by Engineer.ai) : 100
# BW-IVMS : 100
# BV Mobile Apps : 100
# Ag Trucking Mobile App : 100
# Ag Guardian : 100
# My Ag Report : 50
# MY GULFPORT FL : 50
# EY Team Connect : 50
# EB Scanner : 50
# CX Summit : 50
# CT CONNECT : 50
# CONNECT: The Mobile CX Summit : 50
# CE SODEXO PASS FRANCE : 50
# BN DB1 App : 50
# BAMMS for BM 1Park : 50
# SKIN BK : 10
# PLMGSS FR : 10
# My CG : 10
# MinT BI : 10
# EU Brazil Green Business Forum : 10
# ER Assist : 10
# EP Cloud : 10
# EI! : 10
# EC QR : 10
# DV Web Design Tips : 10
# CQ Ukraine : 10
# BW t&t : 10
# BW Ultra : 10
# BN Inscript Improved Keyboard : 10
# BN Inscript Improved Input keyboard : 10
# BM Interventi : 10
# BAMMS for BM SQ : 10
# AQ Guards : 10
# APagri CD : 10
# ACCEPT CE MARKING : 10
# Shaggy's DM Assistant : 5
# FK Events : 5
# EC Sampler : 1
# DZ Register : 1
# DT Freight : 1
# CQ Electrical Group : 1

# %% [markdown]
# --> First places on top dominated by apps from Google and Microsoft. - could be hard to entry...

# %%
table_display=[]
for each in play_en_free_cleaned:
    if each[1] == 'GAME':
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        tupples=(installers, each[0])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Subway Surfers : 1000000000
# Temple Run 2 : 500000000
# Pou : 500000000
# My Talking Tom : 500000000
# Candy Crush Saga : 500000000
# slither.io : 100000000
# Zombie Tsunami : 100000000
# Yes day : 100000000
# Vector : 100000000
# Trivia Crack : 100000000
# Traffic Racer : 100000000
# Temple Run : 100000000
# Talking Tom Gold Run : 100000000
# Super Mario Run : 100000000
# Sonic Dash : 100000000
# Sniper 3D Gun Shooter: Free Shooting Games - FPS : 100000000
# Smash Hit : 100000000
# Skater Boy : 100000000
# Shadow Fight 2 : 100000000
# Score! Hero : 100000000
# Roll the Ball® - slide puzzle : 100000000
# Pokémon GO : 100000000
# Plants vs. Zombies FREE : 100000000
# Piano Tiles 2™ : 100000000
# PAC-MAN : 100000000
# My Talking Angela : 100000000
# Modern Combat 5: eSports FPS : 100000000
# Mobile Legends: Bang Bang : 100000000
# Lep's World 2 🍀🍀 : 100000000
# Jetpack Joyride : 100000000
# Hungry Shark Evolution : 100000000
# Hill Climb Racing 2 : 100000000
# Hill Climb Racing : 100000000
# Helix Jump : 100000000
# Glow Hockey : 100000000
# Geometry Dash Lite : 100000000
# Garena Free Fire : 100000000
# Fruit Ninja® : 100000000
# Flow Free : 100000000
# Extreme Car Driving Simulator : 100000000
# Dream League Soccer 2018 : 100000000
# Dr. Driving : 100000000
# Cut the Rope FULL FREE : 100000000
# Crossy Road : 100000000
# Cooking Fever : 100000000
# Clash of Clans : 100000000
# Clash Royale : 100000000
# Candy Crush Soda Saga : 100000000
# Bus Rush: Subway Edition : 100000000
# Bike Race Free - Top Motorcycle Racing Games : 100000000
# Banana Kong : 100000000
# Asphalt 8: Airborne : 100000000
# Ant Smasher by Best Cool & Fun Games : 100000000
# Angry Birds Star Wars : 100000000
# Angry Birds Rio : 100000000
# Angry Birds Classic : 100000000
# Angry Birds 2 : 100000000
# Agar.io : 100000000
# 8 Ball Pool : 100000000
# ► MultiCraft ― Free Miner! 👍 : 50000000
# Zynga Poker – Texas Holdem : 50000000
# Words With Friends Classic : 50000000
# Word Search : 50000000
# War Robots : 50000000
# UNO ™ & Friends : 50000000
# Toy Truck Rally 3D : 50000000
# Toy Blast : 50000000
# Swamp Attack : 50000000
# Summoners War : 50000000
# Snake VS Block : 50000000
# Shoot Hunter-Gun Killer : 50000000
# Rolling Sky : 50000000
# Red Ball 4 : 50000000
# Racing in Car 2 : 50000000
# Racing Moto : 50000000
# Pixel Gun 3D: Survival shooter & Battle Royale : 50000000
# Piano Free - Keyboard with Magic Tiles Music Games : 50000000
# Perfect Piano : 50000000
# PUBG MOBILE : 50000000
# Need for Speed™ No Limits : 50000000
# Magic Tiles 3 : 50000000
# MARVEL Contest of Champions : 50000000
# Love Balls : 50000000
# Lords Mobile: Battle of the Empires - Strategy RPG : 50000000
# Lep's World 🍀 : 50000000
# Lep's World 3 🍀🍀🍀 : 50000000
# Kick the Buddy : 50000000
# Hungry Shark World : 50000000
# Granny : 50000000
# Geometry Dash Meltdown : 50000000
# Gardenscapes : 50000000
# Gangstar Vegas - mafia game : 50000000
# GUNSHIP BATTLE: Helicopter 3D : 50000000
# Earn to Die 2 : 50000000
# Draw Something Classic : 50000000
# Dr. Parking 4 : 50000000
# Doodle Jump : 50000000
# DEER HUNTER CLASSIC : 50000000
# DEAD TARGET: FPS Zombie Apocalypse Survival Games : 50000000
# Chess Free : 50000000
# Candy Crush Jelly Saga : 50000000
# CATS: Crash Arena Turbo Stars : 50000000
# Bubble Witch 3 Saga : 50000000
# Bowmasters : 50000000
# Block Craft 3D: Building Simulator Games For Free : 50000000
# Bike Racing 3D : 50000000
# Beach Buggy Blitz : 50000000
# BMX Boy : 50000000
# Angry Birds Go! : 50000000
# Angry Birds Friends : 50000000
# Anger of stick 5 : zombie : 50000000
# nds4droid : 10000000
# iGun Pro -The Original Gun App : 10000000
# diep.io : 10000000
# Zombie Hunter: Post Apocalypse Survival Games : 10000000
# Zombie Frontier : 10000000
# Zombie Catchers : 10000000
# World Series of Poker – WSOP Free Texas Holdem : 10000000
# Wordscapes : 10000000
# Words With Friends – Play Free : 10000000
# Word Link : 10000000
# Truck Driver Cargo : 10000000
# Train Racing Games 3D 2 Player : 10000000
# Toon Blast : 10000000
# The Walking Dead: Road to Survival : 10000000
# The Sims™ FreePlay : 10000000
# The Maze Runner : 10000000
# Texas Holdem Poker : 10000000
# Texas Holdem & Omaha Poker: Pokerist : 10000000
# Texas HoldEm Poker Deluxe : 10000000
# Tank Stars : 10000000
# TRANSFORMERS: Forged to Fight : 10000000
# Sweet Fruit Candy : 10000000
# Survival: Prison Escape : 10000000
# Super Jabber Jump : 10000000
# Stupid Zombies : 10000000
# Street Skater 3D : 10000000
# Strange Hero: Future Battle : 10000000
# StirFry Stunts - We Bare Bears : 10000000
# Stick War: Legacy : 10000000
# Standoff 2 : 10000000
# Stack Jump : 10000000
# Squadron - Bullet Hell Shooter : 10000000
# Special Forces Group 2 : 10000000
# Space Shooter : Galaxy Attack : 10000000
# Soul Knight : 10000000
# Sonic the Hedgehog™ Classic : 10000000
# Solitaire! : 10000000
# Solitaire TriPeaks : 10000000
# Solitaire : 10000000
# Sniper Killer Shooter : 10000000
# Slot Machines by IGG : 10000000
# Shooting King : 10000000
# Shoot Strike War Fire : 10000000
# Scratch Logo Quiz. Challenging brain puzzle : 10000000
# San Andreas Crime Stories : 10000000
# Rush : 10000000
# Run Sausage Run! : 10000000
# Rope'n'Fly 4 : 10000000
# Rope'n'Fly 3 - Dusk Till Dawn : 10000000
# Rope Hero: Vice Town : 10000000
# Rolly Vortex : 10000000
# Robbery Bob : 10000000
# Rider : 10000000
# Rento - Dice Board Game Online : 10000000
# Red Hands – 2-Player Games : 10000000
# Real Gangster Crime : 10000000
# Real City Car Driver : 10000000
# Race the Traffic Moto : 10000000
# RULES OF SURVIVAL : 10000000
# Quiz: Logo game : 10000000
# Power Rangers: Legacy Wars : 10000000
# Power Rangers Dino Charge : 10000000
# Power Pop Bubbles : 10000000
# Police Car Driver : 10000000
# Pixel Art: Color by Number Game : 10000000
# Pineapple Pen : 10000000
# Partymasters - Fun Idle Game : 10000000
# Paint Hit : 10000000
# Nyan Cat: Lost In Space : 10000000
# NinJump : 10000000
# Navy Gunner Shoot War 3D : 10000000
# My Boy! Free - GBA Emulator : 10000000
# Motorbike Driving Simulator 3D : 10000000
# Moto Rider : 10000000
# Moto Fighter 3D : 10000000
# Modern Strike Online : 10000000
# Miraculous Ladybug & Cat Noir - The Official Game : 10000000
# Miami crime simulator : 10000000
# Miami Crime Vice Town : 10000000
# Metal Soldiers 2 : 10000000
# Marble Woka Woka 2018 - Bubble Shooter Match 3 : 10000000
# Marble - Temple Quest : 10000000
# Major Mayhem : 10000000
# Mafia City : 10000000
# MORTAL KOMBAT X : 10000000
# MARVEL Avengers Academy : 10000000
# Live Hold’em Pro Poker - Free Casino Games : 10000000
# Last Day on Earth: Survival : 10000000
# Kung Fu Do Fighting : 10000000
# Knife Hit : 10000000
# Kill Shot Bravo: Sniper FPS : 10000000
# KIM KARDASHIAN: HOLLYWOOD : 10000000
# Just Dance Now : 10000000
# Jungle Monkey Run : 10000000
# Jewels Legend - Match 3 Puzzle : 10000000
# Iron Blade : 10000000
# Injustice: Gods Among Us : 10000000
# Ingress : 10000000
# Hustle Castle: Fantasy Kingdom : 10000000
# Homescapes : 10000000
# Hole.io : 10000000
# Heroes Arena : 10000000
# Hello Stars : 10000000
# Heart of Vegas™ Slots – Free Slot Casino Games : 10000000
# Harry Potter: Hogwarts Mystery : 10000000
# Hard Time (Prison Sim) : 10000000
# Guns of Glory : 10000000
# Guns of Boom - Online Shooter : 10000000
# Gun Strike Shoot : 10000000
# Grand Gangsters 3D : 10000000
# Geometry Dash World : 10000000
# Geometry Dash SubZero : 10000000
# Gems or jewels ? : 10000000
# Galaxy Attack: Alien Shooter : 10000000
# Fruits Bomb : 10000000
# Fruit Block - Puzzle Legend : 10000000
# Flip the Gun - Simulator Game : 10000000
# Five Nights at Freddy's 4 Demo : 10000000
# Five Nights at Freddy's 3 Demo : 10000000
# Fishdom : 10000000
# Final Fantasy XV: A New Empire : 10000000
# Fidget Spinner : 10000000
# Fernanfloo : 10000000
# Family Guy The Quest for Stuff : 10000000
# FRONTLINE COMMANDO: D-DAY : 10000000
# FRONTLINE COMMANDO : 10000000
# Eyes - The Scary Horror Game Adventure : 10000000
# Experiment Z - Zombie : 10000000
# Dude Perfect 2 : 10000000
# Draw a Stickman: EPIC Free : 10000000
# Draw a Stickman: EPIC 2 Free : 10000000
# Draw In : 10000000
# Dragon Hills : 10000000
# Dr. Driving 2 : 10000000
# Dino T-Rex : 10000000
# Defender : 10000000
# Deck Heroes: Legacy : 10000000
# Dan the Man: Action Platformer : 10000000
# DRAGON BALL Z DOKKAN BATTLE : 10000000
# DINO HUNTER: DEADLY SHORES : 10000000
# DH Texas Poker - Texas Hold'em : 10000000
# DEER HUNTER 2018 : 10000000
# Critical Ops : 10000000
# Crisis Action: 2018 NO.1 FPS : 10000000
# Crazy Wheels : 10000000
# Cover Fire: offline shooting games for free : 10000000
# Counter Terrorist Attack : 10000000
# Cooking Madness - A Chef's Restaurant Games : 10000000
# Color Road : 10000000
# Choices: Stories You Play : 10000000
# Checkers : 10000000
# Cheating Tom 3 - Genius School : 10000000
# Cash, Inc. Money Clicker Game & Business Adventure : 10000000
# Candy Bomb : 10000000
# Can Knockdown 3 : 10000000
# Call of Mini™ Dino Hunter : 10000000
# Call of Duty®: Heroes : 10000000
# Bunny Skater : 10000000
# Bullet Force : 10000000
# Bubble Shooter : 10000000
# Bounce Classic : 10000000
# Bomber Friends : 10000000
# Blossom Blast Saga : 10000000
# Block Strike : 10000000
# Bike Rivals : 10000000
# Bike Race - Bike Blast Rush : 10000000
# Bike Mayhem Free : 10000000
# Big Hunter : 10000000
# Big Fish Casino – Play Slots & Vegas Games : 10000000
# Best Fiends - Free Puzzle Game : 10000000
# Battlefield™ Companion : 10000000
# Baseball Boy! : 10000000
# BLACKJACK! : 10000000
# BEYBLADE BURST app : 10000000
# Asphalt Xtreme: Rally Racing : 10000000
# Arrow.io : 10000000
# Arena of Valor: 5v5 Arena Game : 10000000
# Alto's Adventure : 10000000
# 1LINE – One Line with One Touch : 10000000
# Word Crossy - A crossword game : 5000000
# Will it Crush? : 5000000
# Wheelie Challenge : 5000000
# War and Order : 5000000
# Toughest Game Ever 2 : 5000000
# Tomb of the Mask : 5000000
# Tiny Archers : 5000000
# The Visitor : 5000000
# The Cube : 5000000
# Texas Holdem Poker Pro : 5000000
# THE KING OF FIGHTERS-A 2012(F) : 5000000
# TEKKEN™ : 5000000
# Survival Run with Bear Grylls : 5000000
# Super Jabber Jump 3 : 5000000
# Snes9x EX+ : 5000000
# Smashy Road: Arena : 5000000
# Sky Streaker - Gumball : 5000000
# Shoot Bubble - Fruit Splash : 5000000
# SCRABBLE : 5000000
# SAMURAI vs ZOMBIES DEFENSE : 5000000
# Rope Hero 3 : 5000000
# Rivals at War: Firefight : 5000000
# Rescue Robots Survival Games : 5000000
# RC Monster Truck - Offroad Driving Simulator : 5000000
# Peggle Blast : 5000000
# PRO MX MOTOCROSS 2 : 5000000
# Oggy : 5000000
# Nights at Cube Pizzeria 3D – 2 : 5000000
# New YAHTZEE® With Buddies Dice Game : 5000000
# NARUTO X BORUTO NINJA VOLTAGE : 5000000
# My OldBoy! Free - GBC Emulator : 5000000
# Motocross Motorbike Simulator Offroad : 5000000
# Mini Golf King - Multiplayer Game : 5000000
# Merge Dragons! : 5000000
# Mad Day - Truck Distance Game : 5000000
# Love Nikki-Dress UP Queen : 5000000
# Lineage 2: Revolution : 5000000
# Last Shelter: Survival : 5000000
# Jurassic World™ Alive : 5000000
# Jungle Marble Blast : 5000000
# Jewels classic Prince : 5000000
# Injustice 2 : 5000000
# I Know Stuff : 5000000
# Hopeless Land: Fight for Survival : 5000000
# Hero Hunters : 5000000
# Hambo : 5000000
# HAWK – Force of an Arcade Shooter. Shoot 'em up : 5000000
# Guess The Emoji : 5000000
# Grim Soul: Dark Fantasy Survival : 5000000
# Governor of Poker 2 - OFFLINE POKER GAME : 5000000
# Golden HoYeah Slots - Real Casino Slots : 5000000
# Glitch Fixers: Powerpuff Girls : 5000000
# Gangster Town : 5000000
# GUN ZOMBIE : 5000000
# Four In A Line Free : 5000000
# Fast like a Fox : 5000000
# FINAL FANTASY BRAVE EXVIUS : 5000000
# Extreme X Ray Robot Stunts : 5000000
# Evil Apples: A Dirty Card Game : 5000000
# ETERNITY WARRIORS 2 : 5000000
# Dr. Gomoku : 5000000
# Does not Commute : 5000000
# Disney Heroes: Battle Mode : 5000000
# Dinosaur Simulator: Dino World : 5000000
# DRAGON BALL LEGENDS : 5000000
# DEER HUNTER RELOADED : 5000000
# DEER HUNTER CHALLENGE : 5000000
# Cytus : 5000000
# CrossFire: Legends : 5000000
# Creative Destruction : 5000000
# Crazy Bike attack Racing New: motorcycle racing : 5000000
# Counter Online FPS Game : 5000000
# Cops N Robbers - FPS Mini Game : 5000000
# Commando Adventure Assassin : 5000000
# Color by Number – New Coloring Book : 5000000
# Classic Words Solo : 5000000
# Chicken Invaders 3 : 5000000
# Cartoon Wars: Blade : 5000000
# Call of Mini™ Zombies 2 : 5000000
# CONTRACT KILLER: ZOMBIES (NR) : 5000000
# CONTRACT KILLER: ZOMBIES : 5000000
# Bubble Shooter Genies : 5000000
# Bubble Shooter 2 : 5000000
# Block Puzzle Classic Legend ! : 5000000
# Block Puzzle : 5000000
# Block Gun 3D: Ghost Ops : 5000000
# Bingo by IGG: Top Bingo+Slots! : 5000000
# Asylum Night Shift - Five Nights Survival : 5000000
# Angry Birds Space HD : 5000000
# AE 3D MOTOR :Racing Games Free : 5000000
# 4 in a row : 5000000
# iSniper 3D Arctic Warfare : 1000000
# Zombie Hunter King : 1000000
# Zombie Death Shooter : 1000000
# Z Champions : 1000000
# Word Search multilingual : 1000000
# Woody Puzzle : 1000000
# WithstandZ - Zombie Survival! : 1000000
# Water Surfer Racing In Moto : 1000000
# WDAMAGE: Car Crash Engine : 1000000
# Voxel - 3D Color by Number & Pixel Coloring Book : 1000000
# Vikings: an Archer's Journey : 1000000
# V for Voodoo : 1000000
# True Skateboarding Ride Skateboard Game Freestyle : 1000000
# Traffic Sniper Counter Attack : 1000000
# Tokyo Ghoul: Dark War : 1000000
# The Walking Zombie: Dead City : 1000000
# The Walking Dead: Our World : 1000000
# The Visitor: Ep.2 - Sleepover Slaughter : 1000000
# The Vikings : 1000000
# The Grand Wars: San Andreas : 1000000
# The Fish Master! : 1000000
# Thai Sic Bo : 1000000
# Texas Hold'em Poker : 1000000
# TerraGenesis - Space Colony : 1000000
# TAMAGO Monsters Returns : 1000000
# Super Jim Jump - pixel 3d : 1000000
# Super Dancer : 1000000
# Sudoku Master : 1000000
# Stickman Warriors Heroes 2 : 1000000
# Speed Racing Ultimate 2 : 1000000
# Space X: Sky Wars of Air Force : 1000000
# Sonic CD Classic : 1000000
# Soccer Clubs Logo Quiz : 1000000
# SnowMobile Parking Adventure : 1000000
# Slendrina X : 1000000
# Skip-Bo™ Free : 1000000
# Shred! Downhill Mountainbiking : 1000000
# Shooter Sniper CS - FPS Games : 1000000
# Shadowverse CCG : 1000000
# STARDOM: THE A-LIST : 1000000
# SHADOWGUN LEGENDS : 1000000
# Rope Superhero Unlimited : 1000000
# Rope Hero Return of a Legend : 1000000
# Robocar X Ray : 1000000
# RetroArch : 1000000
# RC City Police Heavy Traffic Racer : 1000000
# Q*bert: Rebooted : 1000000
# PlayTexas Hold'em Poker Free : 1000000
# Pixel Z Gunner 3D - Battle Survival Fps : 1000000
# Once Upon a Tower : 1000000
# Offroad Outlaws : 1000000
# NDS Emulator - For Android 6 : 1000000
# Mupen64+AE FREE (N64 Emulator) : 1000000
# Multicraft Miner Exploration : 1000000
# Motocross Mayhem : 1000000
# Mopar Drag N Brag : 1000000
# Mini Motor Racing WRT : 1000000
# Mini DAYZ: Zombie Survival : 1000000
# Magnum 3.0 Gun Custom SImulator : 1000000
# Mad Skills Motocross : 1000000
# Mad Skills BMX 2 : 1000000
# MMX Hill Dash 2 – Offroad Truck, Car & Bike Racing : 1000000
# MLB TAP SPORTS BASEBALL 2018 : 1000000
# Love Dance : 1000000
# Looper! : 1000000
# Let's Poke The Egg : 1000000
# LA Stories 4 New Order Sandbox 2018 : 1000000
# L.A. Crime Stories Mad City Crime : 1000000
# Justice League Action Run : 1000000
# Just A Regular Arcade : 1000000
# Jewels Star: OZ adventure : 1000000
# Identity V : 1000000
# Ice Crush 2018 - A new Puzzle Matching Adventure : 1000000
# IV Go（get IV for Pokemon） : 1000000
# I Am Innocent : 1000000
# Horror Hospital : 1000000
# Honkai Impact 3rd : 1000000
# Heroes of Dragon Age : 1000000
# Gun Shoot War Q : 1000000
# Gun Club Armory : 1000000
# Gun Builder ELITE : 1000000
# Gear.Club - True Racing : 1000000
# Gang Wars of San Andreas : 1000000
# Game of Thrones: Conquest™ : 1000000
# G-Switch 2 : 1000000
# Frontline Terrorist Battle Shoot: Free FPS Shooter : 1000000
# Free DS Emulator : 1000000
# Four In A Line : 1000000
# Fields of Battle : 1000000
# Fatal Raid - No.1 Mobile FPS : 1000000
# Fast Racing Car Simulator : 1000000
# Fast Motorcycle Driver 2016 : 1000000
# Farm Fruit Pop: Party Time : 1000000
# Fancy Pants Adventures : 1000000
# Faketalk - Chatbot : 1000000
# FaFaFa™ Gold Casino: Free slot machines : 1000000
# Extreme Super Car Driving 3D : 1000000
# Driving Zone : 1000000
# Drift Legends : 1000000
# Draw N Guess Multiplayer : 1000000
# Draw A Stickman : 1000000
# Dragonplay™ Poker Texas Holdem : 1000000
# Drag'n'Boom : 1000000
# Dr. Shogi : 1000000
# Dr. Rocket : 1000000
# Dr. Parker : Real car parking simulation : 1000000
# Dr. Parker : Parking Simulator : 1000000
# Dr. Chess : 1000000
# Dino War: Rise of Beasts : 1000000
# Destroy Gunners Σ : 1000000
# Cube Z (Pixel Zombies) : 1000000
# Critical Strike CS: Counter Terrorist Online FPS : 1000000
# Counter Attack - Multiplayer FPS : 1000000
# Cops N Robbers 2 : 1000000
# Cops N Robbers : 1000000
# Chapters: Interactive Stories : 1000000
# Casino X - Free Online Slots : 1000000
# Carros Rebaixados BR : 1000000
# Carnivores: Dinosaur Hunter : 1000000
# Car Race by Fun Games For Free : 1000000
# Car Driving Simulator Drift : 1000000
# CKZ ORIGINS : 1000000
# CJ: Strike Back : 1000000
# Bubble Shooter Space : 1000000
# Bricks n Balls : 1000000
# Boyaa Poker (En) – Social Texas Hold’em : 1000000
# BombSquad Remote : 1000000
# Block Gun 3D: Haunted Hollow : 1000000
# Block Gun 3D: Call of Destiny : 1000000
# Blackjack : 1000000
# Bingo Party - Free Bingo Games : 1000000
# Beauty Idol: Fashion Queen : 1000000
# Battlelands Royale : 1000000
# BROTHER IN WARS: GUNNER CITY WARLORDS : 1000000
# BLOOD & GLORY: IMMORTALS : 1000000
# BF Frontline City : 1000000
# Avatar Musik : 1000000
# Auction Wars : Storage King : 1000000
# Au Mobile: Audition Chính Hiệu : 1000000
# Assault Line CS Online Fps Go : 1000000
# Ao Oni2 : 1000000
# Angelo Rules - Crazy day : 1000000
# Adventure Time Run : 1000000
# AU Mobile Indonesia : 1000000
# AE Master Moto : 1000000
# AE Lucky Fishing : 1000000
# AE Gun Ball: arcade ball games : 1000000
# AE Coin Mania : Arcade Fun : 1000000
# 7 Nights at Pixel Pizzeria - 2 : 1000000
# 4x4 Jeep Racer : 1000000
# Zombie Sniper 3D III : 500000
# Zlax.io Zombs Luv Ax : 500000
# ZOMBIE RIPPER : 500000
# World of Warriors: Duel : 500000
# Who am I? (Biblical) : 500000
# U-48 Submarine Commander Free : 500000
# Toy Attack : 500000
# The Visitor: Ep.1 - Kitty Cat Carnage : 500000
# The Great Wobo Escape Ep. 1 : 500000
# The Grand Way : 500000
# The Gang Sniper V. Pocket Edition. : 500000
# Texas Hold’em Poker + | Social : 500000
# SuperBikers 2 : 500000
# Super Dancer VN : 500000
# Sports Car Driving Simulator 2018 : 500000
# Solitaire: Decked Out Ad Free : 500000
# Sid Story : 500000
# Shoot`Em Down: Shooting game : 500000
# Route Z : 500000
# Rage Z: Multiplayer Zombie FPS Online Shooter : 500000
# Punch em : 500000
# Project Grand Auto Town Sandbox Beta : 500000
# PokerStars Play: Free Texas Holdem Poker Game : 500000
# Pacific Navy Fighter C.E. (AS) : 500000
# PLANK! : 500000
# Nights at Cube Pizzeria 3D – 4 : 500000
# Might & Magic: Elemental Guardians : 500000
# MegaNDS (NDS Emulator) : 500000
# Law of Creation: A Playable Manga : 500000
# Hide N Seek : Mini Game : 500000
# Hero Fighter X : 500000
# Helix : 500000
# HANGAME Casino - Baccarat & Texas Hold'em : 500000
# Gunship Modern Combat 3D : 500000
# Grand Bat Superhero Flying Assault Rescue Mission : 500000
# Ghost Hunting camera : 500000
# Get 'Em : 500000
# Fun Texas Hold'em Poker : 500000
# Fate/Grand Order (English) : 500000
# Ez Mirror Match : 500000
# Endless Ducker : 500000
# Eh Amego! : 500000
# Dubai Racing : 500000
# Drive 4x4 Luxury SUV Jeep : 500000
# Dreamland Arcade - Steven Universe : 500000
# Dr. Dominoes : 500000
# Destiny Ninja Shall we date otome games love story : 500000
# Dash Quest Heroes : 500000
# Crime Wars S. Andreas : 500000
# Combat BF: Black Ops 3 : 500000
# Chinese Chess / Co Tuong : 500000
# Camping RV Caravan Parking 3D : 500000
# CS16Client : 500000
# Block Battles: Heroes at War - Multiplayer PVP : 500000
# BlackJack 21 Pro : 500000
# Beach Shoot Em Up: Head Hunter : 500000
# AXE.IO - Brutal Survival Battleground : 500000
# ARK: Survival Evolved : 500000
# AE Spider Solitaire : 500000
# AE Bingo: Offline Bingo Games : 500000
# 4 in a Row : 500000
# Аim Training for CS : 100000
# that's lit : 100000
# Zombie War Z : Hero Survival Rules : 100000
# Your rank CS:GO : 100000
# X-WOLF : 100000
# What Am I? - Brain Teasers : 100000
# Vikings Stickman Axe Fighting : 100000
# Undead Assault : 100000
# Ultimate Quiz for CS:GO - Skins | Cases | Players : 100000
# Ultimate BlackJack 3D FREE : 100000
# Two Nights at jumpscare : 100000
# Them Bombs: co-op board game play with 2-4 friends : 100000
# The Q - Live Trivia Game Network : 100000
# Teen Patti by BL Games : 100000
# Sword of Chaos - Lame du Chaos : 100000
# Super Hero M Craft Run : 100000
# Stick 'Em Up 2 Starter Edition : 100000
# Stack It AR : 100000
# Snowboard Racing Free Fun Game : 100000
# Sin City Hero : Crime Simulator of Vegas : 100000
# Sin City Crime Simulator V - Gangster : 100000
# Sic Bo Online! Free Casino : 100000
# San Andreas: Gang Crime V : 100000
# San Andreas City : Auto Theft Car gangster : 100000
# Runner 3d like : 100000
# Rolling G Sky : 100000
# Rock N' Cash Casino Slots -Free Vegas Slot Games : 100000
# Reload: The Z-Team : 100000
# Rage Fight of Streets - Beat Em Up Game : 100000
# RUN JUMP RUN-fun games for free : 100000
# RIDE ZERO : 100000
# Poker Pro.Fr : 100000
# Poker Live! 3D Texas Hold'em : 100000
# Palavras la cq : 100000
# One Night at Golden Freddy's : 100000
# Offroad drive : 4x4 driving game : 100000
# Nights at Slender Pizzeria 3D : 100000
# Modern Counter Terrorist FPS Shoot : 100000
# Modern Action Commando 3D : 100000
# Mobile CS:GO : 100000
# Mirror’s Edge™ Companion : 100000
# Millionaire : Who want to be? : 100000
# Mental Hospital:EB 2 Lite : 100000
# Master of Eternity(MOE) : 100000
# Mass Effect: Andromeda APEX HQ : 100000
# Magic Tiles - TWICE Edition (K-Pop) : 100000
# Magic Tiles - Blackpink Edition (K-Pop) : 100000
# M3-X5-X6-M-İ3-İ8 RACİNG 2018 : 100000
# M-acceleration 3D Car Racing : 100000
# L.A. Crime Stories 2 Mad City Crime : 100000
# Jungle book-The Great Escape : 100000
# How well do you know me? : 100000
# Hotel Insanity : 100000
# Guns Royale - Multiplayer Blocky Battle Royale : 100000
# Grim Tales: The Wishes CE : 100000
# Grand Stickman Cover V : 100000
# Girls' Frontline : 100000
# Ghost Snap AR Horror Survival : 100000
# G-Switch 3 : 100000
# G-Switch : 100000
# Forgotten Hill: Surgery : 100000
# Forgotten Hill: Puppeteer : 100000
# Forgotten Hill Mementoes : 100000
# Flat Pack : 100000
# Five Nights at Pizzeria : 100000
# Five Nights at Neighbor House : 100000
# Extreme Match : 100000
# Dragon X Adventure: Warrior Z : 100000
# Decay: The Mare - Ep.1 (Trial) : 100000
# DS Tower Defence : 100000
# DJMAX TECHNIKA Q - Music Game : 100000
# DH Pineapple Poker OFC : 100000
# D Day World War II Commando Survival Shooting : 100000
# Combat Strike CS 🔫 Counter Terrorist Attack FPS💣 : 100000
# CT-ART 4.0 (Chess Tactics 1200-2400 ELO) : 100000
# BlackJack -21 Casino Card Game : 100000
# Black Commando | Special Ops | FPS Shooting : 100000
# Betul Ke Bohong Eh? : 100000
# Beach Head Shooting Assault : 100000
# BF Combat: Genesis : 100000
# BEBONCOOL GAMEPAD V1.0 : 100000
# Au-allstar for KR : 100000
# Armored Warfare: Assault : 100000
# Archery Physics Objects Destruction Apple shooter : 100000
# Adivina el cantante de Trap y Reggaeton : 100000
# Adivina el Emoji : 100000
# AH-1 Viper Cobra Ops - helicopter flight simulator : 100000
# AE GTO Racing : 100000
# AE Blackjack : 100000
# AE 3D Moto 3 : 100000
# 5 Nights at Cube Pizzeria City : 100000
# Winter Wonderland : 50000
# Super Car F. Mod for MCPE : 50000
# Stickman and Axe : 50000
# Sniper Traning for CS GO : 50000
# Simple x3DS Emulator - BETA : 50000
# Real Casino:Slot,Keno,BJ,Poker : 50000
# Radial-G : Infinity : 50000
# Quiz TRUE or FALSE : 50000
# Quiz CS:GO players : 50000
# Modern Counter Terror Attack – Shooting Game : 50000
# Modern Counter Global Strike 3D V2 : 50000
# Modern Counter Global Strike 3D : 50000
# MazeMilitia Classic Multiplayer Shooting Game : 50000
# Map Callouts for CS:GO : 50000
# Knife&Axe Throwing : 50000
# Gangster City Auto Theft : 50000
# Freecell CY : 50000
# Free Poker Games : Downtown Casino - Texas Holdem : 50000
# Forgotten Hill: Fall : 50000
# EmuBox - Fast Retro Emulator : 50000
# Drink-O-Tron The Drinking Game : 50000
# Don't Hug Me I'm So Scared : 50000
# Dino Defends king 3 – Dinosaur T rex Hunter Games : 50000
# Dead Target Zombie Shooting US Sniper Killer Squad : 50000
# DK Quiz : 50000
# Chinese Chess ( Xiangqi Free ) : 50000
# China Town Auto Theft 2 : 50000
# CJ Poker Odds Calculator : 50000
# American Sniper City Fight Shooting Assassin : 50000
# Ah! Coins : 50000
# AE Video Poker : 50000
# AE Solitaire : 50000
# AE Jewels : 50000
# ¡Ay Metro! : 10000
# kick the buddy : 10000
# What's Your CS:GO rank? : 10000
# VIP Backgammon Free : Play Backgammon Online : 10000
# Ultimate DC Challenge : 10000
# Texas HoldEm Poker Deluxe (BR) : 10000
# Super DK vs Kong Brother Advanced Free Classic : 10000
# Sic Bo Rave : 10000
# Sic Bo (Tai Xiu) - Multiplayer Casino : 10000
# Sermon on Proverbs CH Spurgeon : 10000
# Santa Panda Bubble Christmas : 10000
# Saiyan Z: Super SSJ Ultimate Combat : 10000
# Rock n Roll Music Quiz Game : 10000
# Puzzle for CS:GO : 10000
# Modern Sniper Strike: Best Commando Action 2k18 : 10000
# Lust in Terror Manor - The Truth Unveiled | Otome : 10000
# Korean Dungeon: K-Word 1000 : 10000
# J-Stars Victory VS Guide : 10000
# GALAK-Z: Variant Mobile : 10000
# Five Nights at Flappy's : 10000
# E.G. Chess Free : 10000
# Dr.Slender Ep 1 Guide (Eng) : 10000
# Dr Driving Racer : 10000
# Dr Dre - Beatmaker : 10000
# Dead Zombie Evil Killer:Axe : 10000
# DM EVOLUTION : 10000
# Counter Terrorist Gun Strike CS: Special Forces : 10000
# Cards Casino:Video Poker & BJ : 10000
# Cardi B Piano Game : 10000
# Car Crash III Beam DH Real Damage Simulator 2018 : 10000
# Bullshite! : 10000
# Bullshit! (Free) : 10000
# Blood Domination - BL Game : 10000
# Ba Cristi : 10000
# BW-Joseki : 10000
# BW-Go Free : 10000
# BMX Boy Bike Stunt Rider Game : 10000
# BJ's Bingo & Gaming Casino : 10000
# BJ Bridge Free (2018) : 10000
# BF at Sea Refueled : 10000
# BC Slots - The Lost Reels FREE : 10000
# Axe Champ : 10000
# Armed Cam Gun Pack : 10000
# Arcraft - AR Sandbox : 10000
# AZ Rockets : 10000
# AR Tank Battle : 10000
# AK-47 3D : 10000
# AG Drive 3D : 10000
# AE Jewels 2: Island Adventures : 10000
# AE FreeCell : 10000
# AE City Jump : 10000
# AE Angry Chef : 10000
# Woodman Deluxe : 5000
# Virtual Dice EX : 5000
# Ultimate Fighter Z : 5000
# Tamago egg : 5000
# Roulette Advisor LITE : 5000
# Robot Fighting Games™ - Real Boxing Champions 3D : 5000
# Race Manager FP : 5000
# Heirs & Graces : 5000
# CNY Slots : Gong Xi Fa Cai 发财机 : 5000
# BW-GnuGo : 5000
# BJ Bridge Acol Beginner 2018 : 5000
# Axe Knight : 5000
# Axe Champion : 5000
# VR AG Racing for Cardboard : 1000
# Super ball DZ : 1000
# Quiz DC : 1000
# Puppy Shooting an AK-47: Platformer Zombie Game : 1000
# Guess the song of J Balvin : 1000
# Guess the Class 🔥 AQW : 1000
# FP Runner : 1000
# FJ Final Join , Circles Game : 1000
# EP Gem Hunter : 1000
# DG Mobile : 1000
# DB Ultra Saiyan Battle : 1000
# Crayola Color Blaster : 1000
# Clash of Axe: Flippy Lumberjack Action X : 1000
# C3-C4-PİCASSO-ELYSEE RACİNG : 1000
# Bu Hangi Youtuber ? : 1000
# Bu Hangi Dizi ? : 1000
# Blackjack aj Poker : 1000
# BZ Zombie VR : 1000
# BW-DGS plugin : 1000
# BJ Bridge Standard American 2018 : 1000
# B@dL!bs Lite : 1000
# Axetatic - Axe Throwing Game : 1000
# Axe Man : 1000
# Alex & Co Quiz : 1000
# AK Blackjack : 1000
# AE Fishing Hunter : 1000
# 2-Player Co-op Zombie Shoot : 1000
# Word Hunt : 500
# Racing CX : 500
# R-EU-READY : 500
# Ludo Dz : 500
# J Balvin Piano Tiles : 500
# DC Universe Quiz : 500
# Basic Strategy Training BJ 21 : 500
# Baby Game Animal Jam Free : 500
# BJ card game blackjack : 500
# AK-47 Assult Rifle: Gun Shooting Simulator Game : 500
# Sniper Gun Shot 3D: Impossible Missions : 100
# Shoot! DX - lights for FREE : 100
# Mad Dash Fo' Cash : 100
# Gate Of Death Ep: 1 : 100
# Flippy Axe : Flip The Knife & Axe Simulator : 100
# Elite Commando Shooting War : 100
# EF Jumper : 100
# Driving Cars Simulator Citroen : 100
# DZ-JOKER : 100
# DF Squid : 100
# Countries of the European Union (Quiz) : 100
# CP Trivia : 100
# BU HANGİ ŞARKI ? - 2018 : 100
# BS Tractor : 100
# BS Chopper : 100
# BL!TZ - Endless : 100
# BJ Strategy Tester : 100
# Axe Champ Hit : 100
# Invasion: Defend EU : 50
# Fo Fo Fish : 50
# Cyborg AX-001 : 50
# Bu Nedir ? : 50
# Bu Hangi Oyun ? : 50
# Bi-Tank : 50
# BZ Fingers : 50
# Axe Throw: Flip Champ Axes Champion Throwing Games : 50
# Axe Champs! Wars : 50
# Animal Hunting: Sniper Shooting : 50
# Trovami se ci riesci : 10
# Out of Bounds BH Demo : 10
# Nedir Bu ? : 10
# Monster Ride Pro : 10
# FK (FlightKid) : 10
# FG SPINNER : 10
# Ew, the small alien : 10
# EC Mover : 10
# DM Adventure : 10
# CQ: Lost In Transmission : 10
# Bu Hangi Ünlü? : 10
# BW Switch : 10
# BL-ED: From BLUE to RED : 10
# 211:CK Lite : 10
# Brick Breaker BR : 5
# Ay Vamos - PJ. Balvin - Piano : 5

# %% [markdown]
# --> Very diversify category. We have many many apps. It could mean that market is a lit bit saturated. Maybe we are interesting in other kind of apps.

# %%
table_display=[]
for each in play_en_free_cleaned:
    if each[1] == 'BOOKS_AND_REFERENCE':
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        tupples=(installers, each[0])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# Google Play Books : 1000000000
# Wattpad 📖 Free Books : 100000000
# Bible : 100000000
# Audiobooks from Audible : 100000000
# Amazon Kindle : 100000000
# Wikipedia : 10000000
# Spanish English Translator : 10000000
# Quran for Android : 10000000
# Oxford Dictionary of English : Free : 10000000
# NOOK: Read eBooks & Magazines : 10000000
# Moon+ Reader : 10000000
# JW Library : 10000000
# HTC Help : 10000000
# FBReader: Favorite Book Reader : 10000000
# English Hindi Dictionary : 10000000
# English Dictionary - Offline : 10000000
# Dictionary.com: Find Definitions for English Words : 10000000
# Dictionary - Merriam-Webster : 10000000
# Dictionary : 10000000
# Cool Reader : 10000000
# Aldiko Book Reader : 10000000
# Al-Quran (Free) : 10000000
# Al'Quran Bahasa Indonesia : 10000000
# Al Quran Indonesia : 10000000
# Read books online : 5000000
# English to Hindi Dictionary : 5000000
# Ebook Reader : 5000000
# Dictionary - WordWeb : 5000000
# Bible KJV : 5000000
# Ancestry : 5000000
# AlReader -any text book reader : 5000000
# Al Quran : EAlim - Translations & MP3 Offline : 5000000
# 50000 Free eBooks & Free AudioBooks : 5000000
# wikiHow: how to do anything : 1000000
# eBoox: book reader fb2 epub zip : 1000000
# Stats Royale for Clash Royale : 1000000
# Satellite AR : 1000000
# ReadEra – free ebook reader : 1000000
# Oxford A-Z of English Usage : 1000000
# My Little Pony AR Guide : 1000000
# Koran Read &MP3 30 Juz Offline : 1000000
# Hafizi Quran 15 lines per page : 1000000
# Golden Dictionary (EN-AR) : 1000000
# Free Books - Spirit Fanfiction and Stories : 1000000
# FamilySearch Tree : 1000000
# English-Myanmar Dictionary : 1000000
# EGW Writings : 1000000
# Cloud of Books : 1000000
# Brilliant Quotes: Life, Love, Family & Motivation : 1000000
# Book store : 1000000
# All Maths Formulas : 1000000
# All Language Translator Free : 1000000
# Al Quran Al karim : 1000000
# Youboox - Livres, BD et magazines : 500000
# SDA Sabbath School Quarterly : 500000
# Recipes of Prophetic Medicine for free : 500000
# Only 30 days in English, the guideline is guaranteed : 500000
# Offline: English to Tagalog Dictionary : 500000
# NOOK Audiobooks : 500000
# NOOK App for NOOK Devices : 500000
# Google I/O 2018 : 500000
# Golden Dictionary (FR-AR) : 500000
# Flybook : 500000
# English to Urdu Dictionary : 500000
# English Persian Dictionary : 500000
# English Grammar Complete Handbook : 500000
# Azpen eReader : 500000
# Al-Quran 30 Juz free copies : 500000
# Al Quran (Tafsir & by Word) : 500000
# cloudLibrary : 100000
# V Made : 100000
# URBANO V 02 instruction manual : 100000
# Surah Al-Waqiah : 100000
# Sabbath School : 100000
# Pdf Book Download - Read Pdf Book : 100000
# Offline English Dictionary : 100000
# Litnet - E-books : 100000
# Hymnes et Louanges : 100000
# How to Write CV : 100000
# Hisnul Al Muslim - Hisn Invocations & Adhkaar : 100000
# Guide (for X-MEN) : 100000
# Free Panda Radio Music : 100000
# Free Book Reader : 100000
# English translation from Bengali : 100000
# EGW Writings 2 : 100000
# Download free book with green book : 100000
# Bible with EGW Comments : 100000
# BakaReader EX : 100000
# Aab e Hayat Full Novel : 100000
# eBoox new: Reader for fb2 epub zip books : 50000
# SH-02J Owner's Manual (Android 8.0) : 50000
# La citadelle du musulman : 50000
# Fertilizer Removal By Crop : 50000
# EZ Quran : 50000
# E-Book Read - Read Book for free : 50000
# DV 2019 - EDV Photo & Form : 50000
# C Programs and Reference : 50000
# C Programs Handbook : 50000
# Bible du Semeur-BDS (French) : 50000
# Al-Muhaffiz : 50000
# TN Patta Citta & EC : 10000
# R Language Reference Guide : 10000
# Kristian Hla Bu : 10000
# Kinot & Eichah for Tisha B'Av : 10000
# Guide for DB Xenoverse 2 : 10000
# Guide for DB Xenoverse : 10000
# English To Shona Dictionary : 10000
# Easy Cv maker 2018 : 10000
# DV 2019 Entry Guide : 10000
# DM Screen : 10000
# Bulgarian French Dictionary Fr : 10000
# Borneo Bible, BM Bible : 10000
# Bootable Methods(USB-CD-DVD) : 10000
# BR Ambedkar Biography & Quotes : 10000
# BD All Sim Offer : 10000
# B&H Kids AR : 10000
# Ay Mohabbat Teri Khatir Novel : 10000
# Ay Hasnain k Nana Milad Naat : 10000
# Anonymous caller detection : 10000
# Ag PhD Field Guide : 10000
# Ag PhD Deficiencies : 10000
# Ae Allah na Dai (Rasa) : 10000
# AP Stamps and Registration : 10000
# Learn R Programming Full : 5000
# Learn CT Scan Of Head : 5000
# Fanfic-FR : 5000
# FA Part 1 & 2 Past Papers Solved Free – Offline : 5000
# EC - AP & Telangana : 5000
# Duaa Ek Ibaadat : 5000
# DC HSEMA : 5000
# CA Laws 2018 (California Laws and Codes) : 5000
# Browsery by Barnes & Noble : 5000
# Bilingual Dictionary Audio App : 5000
# B y H Niños ES : 5000
# AY Sing : 5000
# AW Tozer Devotionals - Daily : 5000
# AC Air condition Troubleshoot,Repair,Maintenance : 5000
# bp e-store : 1000
# Tozer Devotional -Series 1 : 1000
# The SCP Foundation DB fr nn5n : 1000
# The Pursuit of God : 1000
# SA HLA BU : 1000
# R Quick Reference Big Data : 1000
# R Programing Offline Tutorial : 1000
# Painting Lulu DC Super Friends : 1000
# La Fe de Jesus : 1000
# Greek Bible FP (Audio) : 1000
# Florida Statutes (FL Code) : 1000
# Florida - Pocket Brainbook : 1000
# Fix Error Google Playstore : 1000
# EU Data Protection : 1000
# EU Charter : 1000
# EP Research Service : 1000
# EB Annual Meetings : 1000
# Dr. Doug's Tips : 1000
# DV 2018 Winners Guide : 1000
# DC Public Library : 1000
# D. H. Lawrence Poems FREE : 1000
# Chemin (fr) : 1000
# CW Nuclear : 1000
# C Offline Tutorial : 1000
# BM Box : 1000
# BD Fishpedia : 1000
# Arizona Statutes, ARS (AZ Law) : 1000
# Ag PhD Soybean Diseases : 1000
# Ag PhD Planting Population Calculator : 1000
# AE Bulletins : 1000
# SDA Collegiate Quarterly : 500
# Modlitební knížka CZ : 500
# Learn SAP BW on HANA : 500
# Learn SAP BW : 500
# Le Fe de Jesus : 500
# La Fe de Jesús : 500
# Catholic La Bu Zo Kam : 500
# MOD Black for BM : 100
# EU IP Codes : 100
# Cypress College Library : 100
# CompactiMa EC pH Calibration : 100
# BU Alsace : 100
# Anime Mod for BM : 100
# GATE 21 years CS Papers(2011-2018 Solved) : 50
# A-J Media Vault : 50
# Learn R Programming : 10
# Khrifa Hla Bu (Solfa) : 10
# Guide for IMS DB : 10
# CY Spray nozzle : 10
# Guide for R Programming : 5
# EW PDF : 5
# CZ-Help : 5
# BibleRead En Cy Zh Yue : 5

# %%
table_display=[]
for each in play_en_free_cleaned:
    if each[1] == 'FOOD_AND_DRINK':
        installers=each[5]
        installers=installers.replace("+","")
        installers=installers.replace(",","")
        installers=int(installers)
        tupples=(installers, each[0])
        table_display.append(tupples)
table_sorted = sorted(table_display, reverse = True)
for entry in table_sorted:
    print(entry[1], ':', entry[0]) # print name and number of ratings, ordered
# Out:
# foodpanda - Local Food Delivery : 10000000
# Zomato - Restaurant Finder and Food Delivery App : 10000000
# Uber Eats: Local Food Delivery : 10000000
# Tastely : 10000000
# Starbucks : 10000000
# Pizza Hut : 10000000
# McDonald's - McDonald's Japan : 10000000
# McDonald's : 10000000
# Foursquare City Guide : 10000000
# Domino's Pizza USA : 10000000
# Delivery yogi. : 10000000
# Cookpad - FREE recipe search makes fun cooking · musical making! : 10000000
# Cookpad : 10000000
# TheFork - Restaurants booking and special offers : 5000000
# Talabat: Food Delivery : 5000000
# OpenTable: Restaurants Near Me : 5000000
# Grubhub: Food Delivery : 5000000
# Delivery trough - delivery trough delivery trough : 5000000
# Delivery Club-food delivery: pizza, sushi, burger, salad : 5000000
# Cookbook Recipes : 5000000
# Chick-fil-A : 5000000
# Chef - Recipes & Cooking : 5000000
# Allrecipes Dinner Spinner : 5000000
# hellofood - Food Delivery : 1000000
# Yummly Recipes & Shopping List : 1000000
# Wendy’s – Food and Offers : 1000000
# Seamless Food Delivery/Takeout : 1000000
# SUBWAY® : 1000000
# SONIC Drive-In : 1000000
# Refreshing app Free application that can use deal coupons : 1000000
# Pyaterochka : 1000000
# Postmates Food Delivery: Order Eats & Alcohol : 1000000
# Pastry & Cooking (Without Net) : 1000000
# Panera Bread : 1000000
# OpenRice : 1000000
# My CookBook (Recipe Manager) : 1000000
# Kitchen Stories - Recipes & Cooking : 1000000
# Instacart: Grocery Delivery : 1000000
# HungerStation : 1000000
# GialloZafferano: Recipes : 1000000
# Eat24 Food Delivery & Takeout : 1000000
# Eat Fast Prepare "Without Internet" : 1000000
# Dunkin' Donuts : 1000000
# Dr. Oetker recipe ideas : 1000000
# DoorDash - Food Delivery : 1000000
# Delicious Recipes : 1000000
# DELISH KITCHEN - FREE recipe movies make food fun and easy! : 1000000
# BigOven Recipes, Meal Planner, Grocery List & More : 1000000
# BeyondMenu Food Delivery : 1000000
# Whataburger : 500000
# Simple Recipes : 500000
# Recipes Pastries and homemade pies More than 500 recipes for pastries : 500000
# Little Caesars : 500000
# Frigo Magic: Easy recipe idea and anti-waste : 500000
# Debonairs Pizza : 500000
# ChefTap Recipes & Grocery List : 500000
# delivery.com: Order Food, Alcohol & Laundry : 100000
# Recipe Keeper : 100000
# Om Waleed Sweets : 100000
# My Recipes Cookbook : RecetteTek : 100000
# IHOP® : 100000
# Healthy Recipes Free : 100000
# El Pollo Loco - Loco Rewards : 100000
# EatStreet Food Delivery App : 100000
# Easy and quick desserts : 100000
# Easy Recipes : 100000
# Dairy Queen : 100000
# DQ Texas : 100000
# Caviar - Food Delivery : 100000
# Baskin-Robbins : 100000
# BURGER KING® Puerto Rico : 100000
# Arby's : 100000
# 9th stage : 100000
# 3D Metal Piano Keys Keyboard Theme : 100000
# Zaatar w Zeit : 50000
# SarashpazPapion (Cooking with Chef Bowls) : 50000
# Recettes Faciles et Rapides : 50000
# Popeyes® App : 50000
# Munchery: Chef Crafted Fresh Food Delivered : 50000
# Easy and Fast Recipes : 50000
# Easy Healthy Recipes : 50000
# ¿Es Vegan? : 10000
# Sumine side dish - dish recipe side dish : 10000
# Q-Tech Companion App : 10000
# McDelivery Cyprus : 10000
# Gâteau au yaourt : 10000
# B.GOOD : 10000
# Au Bon Pain : 10000
# 50 Healthy Slow Cooker Recipes : 10000
# Bar-B-Q Recipes : 5000
# Woody's Bar-B-Q : 1000
# A&W Restaurants : 1000
# Coupons for Burger King : 500
# BH Recepti : 500
# Jimbo's Pit Bar B-Q : 100
# Food-Aw - Order Food Online in Aruba : 100
# Coupons for Dairy Queen : 100
# BH Açaí : 100
# BAR-B-Q Recipes : 100
# Miller's Bar B-Q : 50
# Bar-B-Q Rib House : 50
# BQ Wings : 50
# AV Anthony's : 50
# Sommelier.BG : 10
# Santa Fe Espresso & News : 10
# CJ Infinity : 10
# BG Burger : 10
# Texas Bar-B-Q Rewards : 5
# AJ-COMICS : 5
# orderin.bm : 1

# %% [markdown]
# ---> Checking Foof and Drinks and Books and References - we take similar conclusions that we saw in ios Dataset. This categories has demand, and we have a variety of ways to follow inside.

# %% [markdown]
# ## Conclusions:

# %% [markdown]
# In this project, we analyzed data about the App Store and Google Play mobile apps with the goal of recommending an app profile that can be profitable for both markets.
#
# We concluded that we have 2 interesting areas to work:
# - in books and reference area: for example taking a popular book (perhaps a more recent book) and turning it into an app could be profitable for both the Google Play and the App Store markets. We need to introduce some kind of novelity, like audio version of the book, quizzes on the book, a forum where people can discuss the book, etc.
# - in food and drink area: for example in what concerns website for receipts, restaurants reservations, etc. In the same way we need to introduce some novelities, interactive apss and adapting to the current days.
